# %% [markdown]
# # **Neural Networks for model selection,**
# # **$\mathcal{C}^{EE}_{\ell} + \mathcal{C}^{TE}_{\ell} + \mathcal{C}^{TT}_{\ell}$ data**
# ## Hu-Sawicki f(R) vs ΛCDM
# Can the NN differentiate between HS f(R) and ΛCDM models at the level of the CMB angular power spectrum?

# %%
#Import packages
import pandas as pd
import numpy as np
import math
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.layers.experimental.preprocessing import Normalization
from matplotlib import pyplot as plt
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ### Read and visualize the data (simulated out of [CLASS](https://github.com/lesgourg/class_public) and the [ESA Planck Archival](https://pla.esac.esa.int/#home))

# %%
#Read the data LCDM & MoG
J = 'joint'
label = '_FR0_e-6_FRn'
planck_df_LCDM_tt = np.genfromtxt('./simulated_data/TT_polarization/ttcls_MoGgrids_noisy_FR0_LCDM.csv', delimiter=',')
planck_df_LCDM_te = np.genfromtxt('./simulated_data/TE_polarization/tecls_MoGgrids_noisy_FR0_LCDM.csv', delimiter=',')
planck_df_LCDM_ee = np.genfromtxt('./simulated_data/EE_polarization/eecls_MoGgrids_noisy_FR0_LCDM.csv', delimiter=',')
planck_cls_LCDM = np.column_stack((planck_df_LCDM_tt[1:], planck_df_LCDM_te[1:], planck_df_LCDM_ee[1:])) # get rid of the first column, i.e. multipole moment l

planck_df_MoG_tt = np.genfromtxt('./simulated_data/TT_polarization/ttcls_MoGgrids_noisy%s.csv'%label, delimiter=',')
planck_df_MoG_te = np.genfromtxt('./simulated_data/TE_polarization/tecls_MoGgrids_noisy%s.csv'%label, delimiter=',')
planck_df_MoG_ee = np.genfromtxt('./simulated_data/EE_polarization/eecls_MoGgrids_noisy%s.csv'%label, delimiter=',')
planck_cls_MoG = np.column_stack((planck_df_MoG_tt[1:], planck_df_MoG_te[1:], planck_df_MoG_ee[1:]))

ls = np.concatenate((planck_df_LCDM_tt[0].flatten(), planck_df_LCDM_te[0].flatten(), planck_df_LCDM_ee[0].flatten()))
#Add the model class: 
LCDM_class = np.zeros(len(planck_cls_LCDM))
MoG_class = np.ones(len(planck_cls_MoG))
#The full arrays (+target):
cls_LCDM_class = np.column_stack((planck_cls_LCDM, LCDM_class))
cls_MoG_class = np.column_stack((planck_cls_MoG, MoG_class))

#Full data set
cls_full_dataset = np.concatenate((planck_cls_LCDM, planck_cls_MoG)) #without the class: x_dataset
dataset_class = np.concatenate((LCDM_class, MoG_class)) #only the class: y_dataset
cls_full_dataset_class = np.concatenate((cls_LCDM_class, cls_MoG_class)) #with the class: xy_dataset

# %%
plt.scatter(ls,planck_cls_LCDM[0]-planck_cls_MoG[0], s=8)
plt.xlabel('${\ell}$')
plt.ylabel('$\mathcal{C}_{\ell}(\Lambda CDM)$ - $\mathcal{C}_{\ell} (MoG)$')
# Out:
# Text(0, 0.5, '$\\mathcal{C}_{\\ell}(\\Lambda CDM)$ - $\\mathcal{C}_{\\ell} (MoG)$')

# %% [markdown]
# ## Angular power spectrum (all the components)

# %%
#-----------------------------------------------------------------------------------------------------------------------
#Plot Cls
#-----------------------------------------------------------------------------------------------------------------------
fig = plt.figure(figsize=(8,6))
plt.scatter(ls,cls_full_dataset[50:][0], label='$\Lambda$CDM', marker='o', s=8)
plt.scatter(ls,cls_full_dataset[50:][249], label='MoG', marker='o', s=8)
plt.xlabel('${\ell}$')
plt.ylabel(' $\mathcal{C}^{EE}_{\ell} + \mathcal{C}^{TE}_{\ell} + \mathcal{C}^{TT}_{\ell}$')
plt.legend()
plt.grid(color='lightgray', linestyle='--')

# %%
#-----------------------------------------------------------------------------------------------------------------------
#Dls
#-----------------------------------------------------------------------------------------------------------------------
# Create a function for converting the C_ls to Dls Tcmb=2.7255
def Dls(l,Cls):
    Dl = [l[i]*(l[i]+1)*Cls[i]/((2*math.pi)*(2.7255*10**6)**2) for i in range(len(l))]
    return Dl
#-----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Z-score normalization of the joint data

# %%
#-------------------------------------------------------------------------------------------------------------
#Normalization and visualization
#-------------------------------------------------------------------------------------------------------------
fig = plt.figure(figsize=(8,6))
normalize = Normalization()
normalize.adapt(cls_full_dataset)
normalized_data = normalize(cls_full_dataset)
plt.scatter(ls,normalized_data[0], label='$\Lambda$CDM', marker='o', s=8)
plt.scatter(ls,normalized_data[-1], label='MoG', marker='o', s=8)
plt.grid(color='lightgray', linestyle='--')
plt.legend()
plt.xlabel('${\ell}$')
plt.ylabel('Normalized $\mathcal{C}^{EE}_{\ell} + \mathcal{C}^{TE}_{\ell} + \mathcal{C}^{TT}_{\ell}$')
#fig.savefig('./figures/Normalized_DimLess_Cls.pdf')
# Out:
# Text(0, 0.5, 'Normalized $\\mathcal{C}^{EE}_{\\ell} + \\mathcal{C}^{TE}_{\\ell} + \\mathcal{C}^{TT}_{\\ell}$')

# %%
#Z-SCORE verification
print('var: %.4f' % np.var(normalized_data))
print('mean: %.4f' % np.mean(normalized_data))
# Out:
# var: 1.0000
# mean: -0.0000

# %% [markdown]
# ### Training the neural networks

# %%
#Train_test_split
from sklearn.model_selection import train_test_split
normalized_data_numpy = normalized_data.numpy()
X_train, X_test, y_train, y_test = train_test_split(normalized_data_numpy, dataset_class, test_size=0.3, random_state=42)
#Training and validation split with fixed random seed
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
#Redefine the model's architecture to display the input layer: (functional API)
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout

inputs = Input(shape=(len(normalized_data[0]),), name='input_layer') #shape=X_train.shape[1],
hidden_layer = Dense(32, activation='relu', name='hidden_layer')(inputs)
dropout_layer = Dropout(rate=0.2, name='dropout_layer')(hidden_layer)
outputs = Dense(1, activation='sigmoid', name='output_layer')(dropout_layer)

#Create the model
model = Model(inputs=inputs, outputs=outputs, name='Angular_PS_NN')

#Model details
model.summary()
# Out:
# Model: "Angular_PS_NN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 215)]             0
#
#  hidden_layer (Dense)        (None, 32)                6912
#
#  dropout_layer (Dropout)     (None, 32)                0
#
#  output_layer (Dense)        (None, 1)                 33
#
# =================================================================
# Total params: 6945 (27.13 KB)
# Trainable params: 6945 (27.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#-----------------------------------------------------------------------------------------------------------
#Training the NN
#-----------------------------------------------------------------------------------------------------------
model.reset_states()
#Compile model:
model.compile(optimizer=Adam(learning_rate=0.0002), loss='binary_crossentropy', metrics=['accuracy'])

#Training:
History = model.fit(X_train, y_train, epochs=1000, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Epoch 1/1000
# 35/35 [==============================] - 1s 13ms/step - loss: 0.7869 - accuracy: 0.5205 - val_loss: 0.7032 - val_accuracy: 0.4714
# Epoch 2/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.7446 - accuracy: 0.5286 - val_loss: 0.7019 - val_accuracy: 0.4607
# Epoch 3/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.7563 - accuracy: 0.4857 - val_loss: 0.6973 - val_accuracy: 0.5000
# Epoch 4/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.7310 - accuracy: 0.5170 - val_loss: 0.6952 - val_accuracy: 0.5357
# Epoch 5/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.7291 - accuracy: 0.5179 - val_loss: 0.6937 - val_accuracy: 0.5071
# Epoch 6/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.7109 - accuracy: 0.5384 - val_loss: 0.6951 - val_accuracy: 0.4714
# Epoch 7/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.7159 - accuracy: 0.5384 - val_loss: 0.6926 - val_accuracy: 0.4821
# Epoch 8/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.7096 - accuracy: 0.5304 - val_loss: 0.7012 - val_accuracy: 0.4857
# Epoch 9/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.7139 - accuracy: 0.5250 - val_loss: 0.6912 - val_accuracy: 0.5000
# Epoch 10/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6943 - accuracy: 0.5420 - val_loss: 0.6857 - val_accuracy: 0.5821
# Epoch 11/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6929 - accuracy: 0.5286 - val_loss: 0.6845 - val_accuracy: 0.5071
# Epoch 12/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6886 - accuracy: 0.5589 - val_loss: 0.6876 - val_accuracy: 0.5607
# Epoch 13/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6868 - accuracy: 0.5634 - val_loss: 0.6857 - val_accuracy: 0.4536
# Epoch 14/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.7020 - accuracy: 0.5366 - val_loss: 0.6835 - val_accuracy: 0.4500
# Epoch 15/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6807 - accuracy: 0.5616 - val_loss: 0.6812 - val_accuracy: 0.5393
# Epoch 16/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6822 - accuracy: 0.5634 - val_loss: 0.6818 - val_accuracy: 0.5107
# Epoch 17/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6915 - accuracy: 0.5446 - val_loss: 0.6810 - val_accuracy: 0.5036
# Epoch 18/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6880 - accuracy: 0.5545 - val_loss: 0.6744 - val_accuracy: 0.5964
# Epoch 19/1000
# 35/35 [==============================] - 0s 7ms/step - loss: 0.6780 - accuracy: 0.5589 - val_loss: 0.6779 - val_accuracy: 0.5536
# Epoch 20/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6800 - accuracy: 0.5795 - val_loss: 0.6759 - val_accuracy: 0.5143
# Epoch 21/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6861 - accuracy: 0.5393 - val_loss: 0.6776 - val_accuracy: 0.4893
# Epoch 22/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6810 - accuracy: 0.5777 - val_loss: 0.6709 - val_accuracy: 0.6143
# Epoch 23/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6807 - accuracy: 0.5545 - val_loss: 0.6710 - val_accuracy: 0.5679
# Epoch 24/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.6707 - accuracy: 0.5786 - val_loss: 0.6807 - val_accuracy: 0.4750
# Epoch 25/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6811 - accuracy: 0.5634 - val_loss: 0.6726 - val_accuracy: 0.4750
# Epoch 26/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6643 - accuracy: 0.5884 - val_loss: 0.6697 - val_accuracy: 0.5607
# Epoch 27/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6723 - accuracy: 0.5777 - val_loss: 0.6686 - val_accuracy: 0.5571
# Epoch 28/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6690 - accuracy: 0.5634 - val_loss: 0.6662 - val_accuracy: 0.5679
# Epoch 29/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6691 - accuracy: 0.5768 - val_loss: 0.6692 - val_accuracy: 0.4714
# Epoch 30/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6642 - accuracy: 0.5777 - val_loss: 0.6722 - val_accuracy: 0.5429
# Epoch 31/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6657 - accuracy: 0.5991 - val_loss: 0.6646 - val_accuracy: 0.5786
# Epoch 32/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6631 - accuracy: 0.5991 - val_loss: 0.6631 - val_accuracy: 0.5214
# Epoch 33/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6609 - accuracy: 0.5991 - val_loss: 0.6611 - val_accuracy: 0.5750
# Epoch 34/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6630 - accuracy: 0.5991 - val_loss: 0.6624 - val_accuracy: 0.5571
# Epoch 35/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.6662 - accuracy: 0.5661 - val_loss: 0.6622 - val_accuracy: 0.5571
# Epoch 36/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.6591 - accuracy: 0.5848 - val_loss: 0.6636 - val_accuracy: 0.5500
# Epoch 37/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6575 - accuracy: 0.6071 - val_loss: 0.6556 - val_accuracy: 0.5857
# Epoch 38/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6662 - accuracy: 0.5839 - val_loss: 0.6591 - val_accuracy: 0.5750
# Epoch 39/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.6596 - accuracy: 0.5911 - val_loss: 0.6550 - val_accuracy: 0.5893
# Epoch 40/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6521 - accuracy: 0.6125 - val_loss: 0.6532 - val_accuracy: 0.6214
# Epoch 41/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6541 - accuracy: 0.6062 - val_loss: 0.6566 - val_accuracy: 0.6071
# Epoch 42/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6544 - accuracy: 0.6009 - val_loss: 0.6529 - val_accuracy: 0.6036
# Epoch 43/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6547 - accuracy: 0.6054 - val_loss: 0.6473 - val_accuracy: 0.6000
# Epoch 44/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6531 - accuracy: 0.5964 - val_loss: 0.6503 - val_accuracy: 0.6214
# Epoch 45/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6536 - accuracy: 0.5884 - val_loss: 0.6524 - val_accuracy: 0.6036
# Epoch 46/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6469 - accuracy: 0.6062 - val_loss: 0.6496 - val_accuracy: 0.6036
# Epoch 47/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6510 - accuracy: 0.6062 - val_loss: 0.6489 - val_accuracy: 0.6000
# Epoch 48/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6418 - accuracy: 0.6134 - val_loss: 0.6534 - val_accuracy: 0.5750
# Epoch 49/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6517 - accuracy: 0.6009 - val_loss: 0.6447 - val_accuracy: 0.6000
# Epoch 50/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.6400 - accuracy: 0.6509 - val_loss: 0.6416 - val_accuracy: 0.6393
# Epoch 51/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6432 - accuracy: 0.6089 - val_loss: 0.6417 - val_accuracy: 0.6107
# Epoch 52/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6400 - accuracy: 0.6009 - val_loss: 0.6432 - val_accuracy: 0.5714
# Epoch 53/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6351 - accuracy: 0.6304 - val_loss: 0.6417 - val_accuracy: 0.5786
# Epoch 54/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.6386 - accuracy: 0.6277 - val_loss: 0.6364 - val_accuracy: 0.6429
# Epoch 55/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.6354 - accuracy: 0.6634 - val_loss: 0.6381 - val_accuracy: 0.6107
# Epoch 56/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6329 - accuracy: 0.6562 - val_loss: 0.6336 - val_accuracy: 0.6607
# Epoch 57/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6337 - accuracy: 0.6232 - val_loss: 0.6357 - val_accuracy: 0.6500
# Epoch 58/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6355 - accuracy: 0.6196 - val_loss: 0.6348 - val_accuracy: 0.5929
# Epoch 59/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6277 - accuracy: 0.6625 - val_loss: 0.6403 - val_accuracy: 0.5607
# Epoch 60/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6284 - accuracy: 0.6187 - val_loss: 0.6339 - val_accuracy: 0.6000
# Epoch 61/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6287 - accuracy: 0.6625 - val_loss: 0.6270 - val_accuracy: 0.6929
# Epoch 62/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6312 - accuracy: 0.6223 - val_loss: 0.6275 - val_accuracy: 0.6679
# Epoch 63/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.6260 - accuracy: 0.6482 - val_loss: 0.6297 - val_accuracy: 0.6679
# Epoch 64/1000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.6258 - accuracy: 0.6339 - val_loss: 0.6255 - val_accuracy: 0.6036
# Epoch 65/1000
# 35/35 [==============================] - 0s 7ms/step - loss: 0.6267 - accuracy: 0.6304 - val_loss: 0.6246 - val_accuracy: 0.6357
# Epoch 66/1000
# 35/35 [==============================] - 0s 7ms/step - loss: 0.6257 - accuracy: 0.6571 - val_loss: 0.6270 - val_accuracy: 0.6214
# Epoch 67/1000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.6222 - accuracy: 0.6375 - val_loss: 0.6262 - val_accuracy: 0.6071
# Epoch 68/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6205 - accuracy: 0.6598 - val_loss: 0.6192 - val_accuracy: 0.6679
# Epoch 69/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6186 - accuracy: 0.6598 - val_loss: 0.6189 - val_accuracy: 0.6714
# Epoch 70/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6102 - accuracy: 0.6705 - val_loss: 0.6189 - val_accuracy: 0.6250
# Epoch 71/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.6199 - accuracy: 0.6214 - val_loss: 0.6267 - val_accuracy: 0.6250
# Epoch 72/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6208 - accuracy: 0.6625 - val_loss: 0.6141 - val_accuracy: 0.7179
# Epoch 73/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.6129 - accuracy: 0.6536 - val_loss: 0.6155 - val_accuracy: 0.6393
# Epoch 74/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6095 - accuracy: 0.6893 - val_loss: 0.6110 - val_accuracy: 0.6964
# Epoch 75/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.6065 - accuracy: 0.6821 - val_loss: 0.6170 - val_accuracy: 0.6107
# Epoch 76/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.6122 - accuracy: 0.6259 - val_loss: 0.6059 - val_accuracy: 0.7607
# Epoch 77/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.6137 - accuracy: 0.6589 - val_loss: 0.6304 - val_accuracy: 0.5786
# Epoch 78/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.6141 - accuracy: 0.6464 - val_loss: 0.6113 - val_accuracy: 0.6679
# Epoch 79/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.6129 - accuracy: 0.6786 - val_loss: 0.6111 - val_accuracy: 0.6107
# Epoch 80/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6072 - accuracy: 0.6473 - val_loss: 0.6026 - val_accuracy: 0.6964
# Epoch 81/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6053 - accuracy: 0.7134 - val_loss: 0.6015 - val_accuracy: 0.7179
# Epoch 82/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6007 - accuracy: 0.6866 - val_loss: 0.6010 - val_accuracy: 0.7929
# Epoch 83/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5980 - accuracy: 0.6893 - val_loss: 0.6020 - val_accuracy: 0.7393
# Epoch 84/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.6009 - accuracy: 0.6812 - val_loss: 0.5997 - val_accuracy: 0.7321
# Epoch 85/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.6012 - accuracy: 0.6661 - val_loss: 0.6041 - val_accuracy: 0.6679
# Epoch 86/1000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.5986 - accuracy: 0.6911 - val_loss: 0.5994 - val_accuracy: 0.7571
# Epoch 87/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5983 - accuracy: 0.6839 - val_loss: 0.5955 - val_accuracy: 0.7107
# Epoch 88/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5969 - accuracy: 0.7214 - val_loss: 0.5970 - val_accuracy: 0.7857
# Epoch 89/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5920 - accuracy: 0.6973 - val_loss: 0.5904 - val_accuracy: 0.7786
# Epoch 90/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5889 - accuracy: 0.7063 - val_loss: 0.5930 - val_accuracy: 0.7393
# Epoch 91/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5897 - accuracy: 0.6866 - val_loss: 0.5929 - val_accuracy: 0.7857
# Epoch 92/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5952 - accuracy: 0.6902 - val_loss: 0.5948 - val_accuracy: 0.7036
# Epoch 93/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5908 - accuracy: 0.6786 - val_loss: 0.5860 - val_accuracy: 0.7857
# Epoch 94/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5873 - accuracy: 0.7018 - val_loss: 0.5861 - val_accuracy: 0.7821
# Epoch 95/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5880 - accuracy: 0.7045 - val_loss: 0.5901 - val_accuracy: 0.6929
# Epoch 96/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5848 - accuracy: 0.7161 - val_loss: 0.5855 - val_accuracy: 0.7607
# Epoch 97/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5869 - accuracy: 0.6991 - val_loss: 0.5825 - val_accuracy: 0.7036
# Epoch 98/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5797 - accuracy: 0.6964 - val_loss: 0.5807 - val_accuracy: 0.7214
# Epoch 99/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5792 - accuracy: 0.6830 - val_loss: 0.5788 - val_accuracy: 0.7143
# Epoch 100/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5788 - accuracy: 0.7134 - val_loss: 0.5782 - val_accuracy: 0.7536
# Epoch 101/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5832 - accuracy: 0.6839 - val_loss: 0.5826 - val_accuracy: 0.7286
# Epoch 102/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5796 - accuracy: 0.7134 - val_loss: 0.5771 - val_accuracy: 0.7643
# Epoch 103/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5792 - accuracy: 0.7009 - val_loss: 0.5818 - val_accuracy: 0.7393
# Epoch 104/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5812 - accuracy: 0.7000 - val_loss: 0.5727 - val_accuracy: 0.7679
# Epoch 105/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5747 - accuracy: 0.7170 - val_loss: 0.5734 - val_accuracy: 0.7643
# Epoch 106/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5748 - accuracy: 0.7080 - val_loss: 0.5748 - val_accuracy: 0.7857
# Epoch 107/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5762 - accuracy: 0.7188 - val_loss: 0.5765 - val_accuracy: 0.7750
# Epoch 108/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5741 - accuracy: 0.7304 - val_loss: 0.5698 - val_accuracy: 0.7750
# Epoch 109/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5704 - accuracy: 0.7232 - val_loss: 0.5743 - val_accuracy: 0.7036
# Epoch 110/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5688 - accuracy: 0.7196 - val_loss: 0.5652 - val_accuracy: 0.7536
# Epoch 111/1000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.5657 - accuracy: 0.7241 - val_loss: 0.5684 - val_accuracy: 0.7750
# Epoch 112/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5628 - accuracy: 0.7205 - val_loss: 0.5698 - val_accuracy: 0.7964
# Epoch 113/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5618 - accuracy: 0.7473 - val_loss: 0.5621 - val_accuracy: 0.7893
# Epoch 114/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5625 - accuracy: 0.7232 - val_loss: 0.5667 - val_accuracy: 0.7357
# Epoch 115/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5647 - accuracy: 0.7196 - val_loss: 0.5586 - val_accuracy: 0.7893
# Epoch 116/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5638 - accuracy: 0.7179 - val_loss: 0.5576 - val_accuracy: 0.7679
# Epoch 117/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5595 - accuracy: 0.7339 - val_loss: 0.5555 - val_accuracy: 0.7857
# Epoch 118/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5582 - accuracy: 0.7259 - val_loss: 0.5668 - val_accuracy: 0.8107
# Epoch 119/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5626 - accuracy: 0.7286 - val_loss: 0.5530 - val_accuracy: 0.7643
# Epoch 120/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5570 - accuracy: 0.7223 - val_loss: 0.5499 - val_accuracy: 0.7464
# Epoch 121/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5581 - accuracy: 0.7295 - val_loss: 0.5524 - val_accuracy: 0.7643
# Epoch 122/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5536 - accuracy: 0.7312 - val_loss: 0.5511 - val_accuracy: 0.7571
# Epoch 123/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5563 - accuracy: 0.7250 - val_loss: 0.5556 - val_accuracy: 0.7393
# Epoch 124/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5562 - accuracy: 0.7161 - val_loss: 0.5565 - val_accuracy: 0.7393
# Epoch 125/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5488 - accuracy: 0.7339 - val_loss: 0.5464 - val_accuracy: 0.7750
# Epoch 126/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5466 - accuracy: 0.7295 - val_loss: 0.5525 - val_accuracy: 0.8000
# Epoch 127/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5498 - accuracy: 0.7437 - val_loss: 0.5525 - val_accuracy: 0.7286
# Epoch 128/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5465 - accuracy: 0.7437 - val_loss: 0.5458 - val_accuracy: 0.7679
# Epoch 129/1000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.5473 - accuracy: 0.7312 - val_loss: 0.5487 - val_accuracy: 0.8179
# Epoch 130/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5502 - accuracy: 0.7473 - val_loss: 0.5456 - val_accuracy: 0.8036
# Epoch 131/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5463 - accuracy: 0.7223 - val_loss: 0.5381 - val_accuracy: 0.7500
# Epoch 132/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5452 - accuracy: 0.7321 - val_loss: 0.5412 - val_accuracy: 0.7607
# Epoch 133/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5461 - accuracy: 0.7330 - val_loss: 0.5396 - val_accuracy: 0.7464
# Epoch 134/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5431 - accuracy: 0.7509 - val_loss: 0.5345 - val_accuracy: 0.7714
# Epoch 135/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5424 - accuracy: 0.7437 - val_loss: 0.5440 - val_accuracy: 0.7179
# Epoch 136/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5467 - accuracy: 0.7188 - val_loss: 0.5331 - val_accuracy: 0.7429
# Epoch 137/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5405 - accuracy: 0.7375 - val_loss: 0.5516 - val_accuracy: 0.7250
# Epoch 138/1000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.5455 - accuracy: 0.7259 - val_loss: 0.5261 - val_accuracy: 0.7679
# Epoch 139/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5366 - accuracy: 0.7339 - val_loss: 0.5372 - val_accuracy: 0.7714
# Epoch 140/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5319 - accuracy: 0.7616 - val_loss: 0.5298 - val_accuracy: 0.7964
# Epoch 141/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5382 - accuracy: 0.7330 - val_loss: 0.5291 - val_accuracy: 0.7786
# Epoch 142/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5317 - accuracy: 0.7402 - val_loss: 0.5376 - val_accuracy: 0.7929
# Epoch 143/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5319 - accuracy: 0.7437 - val_loss: 0.5282 - val_accuracy: 0.7786
# Epoch 144/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5326 - accuracy: 0.7375 - val_loss: 0.5237 - val_accuracy: 0.7821
# Epoch 145/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5322 - accuracy: 0.7339 - val_loss: 0.5277 - val_accuracy: 0.8000
# Epoch 146/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5355 - accuracy: 0.7384 - val_loss: 0.5253 - val_accuracy: 0.7786
# Epoch 147/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5287 - accuracy: 0.7223 - val_loss: 0.5318 - val_accuracy: 0.7464
# Epoch 148/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5333 - accuracy: 0.7357 - val_loss: 0.5209 - val_accuracy: 0.7786
# Epoch 149/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5296 - accuracy: 0.7473 - val_loss: 0.5217 - val_accuracy: 0.7786
# Epoch 150/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5224 - accuracy: 0.7339 - val_loss: 0.5314 - val_accuracy: 0.7679
# Epoch 151/1000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.5289 - accuracy: 0.7375 - val_loss: 0.5169 - val_accuracy: 0.7929
# Epoch 152/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5183 - accuracy: 0.7563 - val_loss: 0.5181 - val_accuracy: 0.8143
# Epoch 153/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5218 - accuracy: 0.7402 - val_loss: 0.5232 - val_accuracy: 0.8143
# Epoch 154/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5189 - accuracy: 0.7402 - val_loss: 0.5225 - val_accuracy: 0.8143
# Epoch 155/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5290 - accuracy: 0.7250 - val_loss: 0.5196 - val_accuracy: 0.8179
# Epoch 156/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5230 - accuracy: 0.7384 - val_loss: 0.5214 - val_accuracy: 0.7286
# Epoch 157/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5184 - accuracy: 0.7384 - val_loss: 0.5301 - val_accuracy: 0.7250
# Epoch 158/1000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.5250 - accuracy: 0.7321 - val_loss: 0.5147 - val_accuracy: 0.8143
# Epoch 159/1000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.5173 - accuracy: 0.7643 - val_loss: 0.5072 - val_accuracy: 0.7607
# Epoch 160/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5161 - accuracy: 0.7500 - val_loss: 0.5122 - val_accuracy: 0.8000
# Epoch 161/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5138 - accuracy: 0.7464 - val_loss: 0.5065 - val_accuracy: 0.7964
# Epoch 162/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5128 - accuracy: 0.7652 - val_loss: 0.5109 - val_accuracy: 0.7893
# Epoch 163/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5114 - accuracy: 0.7348 - val_loss: 0.5048 - val_accuracy: 0.7821
# Epoch 164/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5140 - accuracy: 0.7393 - val_loss: 0.5111 - val_accuracy: 0.8000
# Epoch 165/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5104 - accuracy: 0.7509 - val_loss: 0.5047 - val_accuracy: 0.7929
# Epoch 166/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5091 - accuracy: 0.7634 - val_loss: 0.5143 - val_accuracy: 0.7679
# Epoch 167/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5134 - accuracy: 0.7482 - val_loss: 0.5081 - val_accuracy: 0.7714
# Epoch 168/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5071 - accuracy: 0.7634 - val_loss: 0.5016 - val_accuracy: 0.7750
# Epoch 169/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5036 - accuracy: 0.7491 - val_loss: 0.5027 - val_accuracy: 0.7893
# Epoch 170/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5028 - accuracy: 0.7580 - val_loss: 0.5072 - val_accuracy: 0.7857
# Epoch 171/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5067 - accuracy: 0.7589 - val_loss: 0.4955 - val_accuracy: 0.7821
# Epoch 172/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5022 - accuracy: 0.7491 - val_loss: 0.4942 - val_accuracy: 0.7929
# Epoch 173/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5063 - accuracy: 0.7509 - val_loss: 0.4943 - val_accuracy: 0.7893
# Epoch 174/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5021 - accuracy: 0.7607 - val_loss: 0.4975 - val_accuracy: 0.8036
# Epoch 175/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5089 - accuracy: 0.7589 - val_loss: 0.4931 - val_accuracy: 0.8143
# Epoch 176/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5024 - accuracy: 0.7661 - val_loss: 0.4923 - val_accuracy: 0.7857
# Epoch 177/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5044 - accuracy: 0.7420 - val_loss: 0.4970 - val_accuracy: 0.7821
# Epoch 178/1000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.5157 - accuracy: 0.7152 - val_loss: 0.4933 - val_accuracy: 0.7964
# Epoch 179/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5078 - accuracy: 0.7464 - val_loss: 0.5016 - val_accuracy: 0.8250
# Epoch 180/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5030 - accuracy: 0.7688 - val_loss: 0.4926 - val_accuracy: 0.8250
# Epoch 181/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5049 - accuracy: 0.7527 - val_loss: 0.4972 - val_accuracy: 0.7964
# Epoch 182/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.4943 - accuracy: 0.7634 - val_loss: 0.4902 - val_accuracy: 0.7643
# Epoch 183/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.4936 - accuracy: 0.7589 - val_loss: 0.4943 - val_accuracy: 0.7786
# Epoch 184/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5016 - accuracy: 0.7455 - val_loss: 0.4995 - val_accuracy: 0.7679
# Epoch 185/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5021 - accuracy: 0.7607 - val_loss: 0.4939 - val_accuracy: 0.8000
# Epoch 186/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4962 - accuracy: 0.7705 - val_loss: 0.4851 - val_accuracy: 0.7893
# Epoch 187/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4984 - accuracy: 0.7393 - val_loss: 0.4947 - val_accuracy: 0.7929
# Epoch 188/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.4964 - accuracy: 0.7616 - val_loss: 0.4818 - val_accuracy: 0.8000
# Epoch 189/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4873 - accuracy: 0.7688 - val_loss: 0.4834 - val_accuracy: 0.8393
# Epoch 190/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.4953 - accuracy: 0.7768 - val_loss: 0.4779 - val_accuracy: 0.8143
# Epoch 191/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.4933 - accuracy: 0.7652 - val_loss: 0.4911 - val_accuracy: 0.8143
# Epoch 192/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4902 - accuracy: 0.7714 - val_loss: 0.4856 - val_accuracy: 0.7571
# Epoch 193/1000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.4907 - accuracy: 0.7589 - val_loss: 0.4890 - val_accuracy: 0.7607
# Epoch 194/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4844 - accuracy: 0.7714 - val_loss: 0.4813 - val_accuracy: 0.8107
# Epoch 195/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4853 - accuracy: 0.7714 - val_loss: 0.4834 - val_accuracy: 0.7821
# Epoch 196/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.4926 - accuracy: 0.7634 - val_loss: 0.4782 - val_accuracy: 0.8107
# Epoch 197/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.4858 - accuracy: 0.7688 - val_loss: 0.4881 - val_accuracy: 0.8321
# Epoch 198/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.4790 - accuracy: 0.7723 - val_loss: 0.4692 - val_accuracy: 0.7893
# Epoch 199/1000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.4862 - accuracy: 0.7705 - val_loss: 0.4758 - val_accuracy: 0.7857
# Epoch 200/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.4842 - accuracy: 0.7795 - val_loss: 0.4732 - val_accuracy: 0.8036
# Epoch 201/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0
# 35/35 [==============================] - 1s 21ms/step - loss: 0.2968 - accuracy: 0.8679 - val_loss: 0.2729 - val_accuracy: 0.8821
# Epoch 939/1000
# 35/35 [==============================] - 1s 21ms/step - loss: 0.3068 - accuracy: 0.8446 - val_loss: 0.3744 - val_accuracy: 0.8250
# Epoch 940/1000
# 35/35 [==============================] - 1s 31ms/step - loss: 0.3272 - accuracy: 0.8393 - val_loss: 0.2846 - val_accuracy: 0.8893
# Epoch 941/1000
# 35/35 [==============================] - 1s 24ms/step - loss: 0.3235 - accuracy: 0.8402 - val_loss: 0.2812 - val_accuracy: 0.8929
# Epoch 942/1000
# 35/35 [==============================] - 1s 22ms/step - loss: 0.2986 - accuracy: 0.8652 - val_loss: 0.2791 - val_accuracy: 0.8714
# Epoch 943/1000
# 35/35 [==============================] - 1s 22ms/step - loss: 0.3000 - accuracy: 0.8616 - val_loss: 0.2820 - val_accuracy: 0.9071
# Epoch 944/1000
# 35/35 [==============================] - 1s 26ms/step - loss: 0.3158 - accuracy: 0.8446 - val_loss: 0.2863 - val_accuracy: 0.8643
# Epoch 945/1000
# 35/35 [==============================] - 1s 23ms/step - loss: 0.3034 - accuracy: 0.8536 - val_loss: 0.2856 - val_accuracy: 0.9429
# Epoch 946/1000
# 35/35 [==============================] - 1s 31ms/step - loss: 0.3037 - accuracy: 0.8580 - val_loss: 0.2770 - val_accuracy: 0.9000
# Epoch 947/1000
# 35/35 [==============================] - 1s 29ms/step - loss: 0.3126 - accuracy: 0.8545 - val_loss: 0.2880 - val_accuracy: 0.8857
# Epoch 948/1000
# 35/35 [==============================] - 1s 19ms/step - loss: 0.3028 - accuracy: 0.8643 - val_loss: 0.2801 - val_accuracy: 0.8714
# Epoch 949/1000
# 35/35 [==============================] - 1s 16ms/step - loss: 0.2894 - accuracy: 0.8723 - val_loss: 0.2719 - val_accuracy: 0.8857
# Epoch 950/1000
# 35/35 [==============================] - 1s 23ms/step - loss: 0.3071 - accuracy: 0.8589 - val_loss: 0.2756 - val_accuracy: 0.9000
# Epoch 951/1000
# 35/35 [==============================] - 1s 18ms/step - loss: 0.3018 - accuracy: 0.8661 - val_loss: 0.2652 - val_accuracy: 0.8893
# Epoch 952/1000
# 35/35 [==============================] - 1s 17ms/step - loss: 0.3067 - accuracy: 0.8545 - val_loss: 0.2757 - val_accuracy: 0.8679
# Epoch 953/1000
# 35/35 [==============================] - 1s 18ms/step - loss: 0.2991 - accuracy: 0.8634 - val_loss: 0.2689 - val_accuracy: 0.8964
# Epoch 954/1000
# 35/35 [==============================] - 1s 24ms/step - loss: 0.3019 - accuracy: 0.8652 - val_loss: 0.2708 - val_accuracy: 0.9000
# Epoch 955/1000
# 35/35 [==============================] - 1s 18ms/step - loss: 0.3005 - accuracy: 0.8687 - val_loss: 0.2763 - val_accuracy: 0.9000
# Epoch 956/1000
# 35/35 [==============================] - 1s 24ms/step - loss: 0.3285 - accuracy: 0.8411 - val_loss: 0.2737 - val_accuracy: 0.9000
# Epoch 957/1000
# 35/35 [==============================] - 1s 18ms/step - loss: 0.3126 - accuracy: 0.8518 - val_loss: 0.2761 - val_accuracy: 0.9143
# Epoch 958/1000
# 35/35 [==============================] - 1s 16ms/step - loss: 0.3160 - accuracy: 0.8420 - val_loss: 0.2959 - val_accuracy: 0.8714
# Epoch 959/1000
# 35/35 [==============================] - 1s 14ms/step - loss: 0.3003 - accuracy: 0.8438 - val_loss: 0.2665 - val_accuracy: 0.9000
# Epoch 960/1000
# 35/35 [==============================] - 1s 20ms/step - loss: 0.3201 - accuracy: 0.8446 - val_loss: 0.2802 - val_accuracy: 0.9321
# Epoch 961/1000
# 35/35 [==============================] - 1s 14ms/step - loss: 0.3027 - accuracy: 0.8616 - val_loss: 0.2704 - val_accuracy: 0.8821
# Epoch 962/1000
# 35/35 [==============================] - 1s 16ms/step - loss: 0.2925 - accuracy: 0.8705 - val_loss: 0.2762 - val_accuracy: 0.8893
# Epoch 963/1000
# 35/35 [==============================] - 1s 22ms/step - loss: 0.2979 - accuracy: 0.8598 - val_loss: 0.2682 - val_accuracy: 0.9036
# Epoch 964/1000
# 35/35 [==============================] - 1s 19ms/step - loss: 0.3166 - accuracy: 0.8411 - val_loss: 0.2764 - val_accuracy: 0.8750
# Epoch 965/1000
# 35/35 [==============================] - 1s 20ms/step - loss: 0.2994 - accuracy: 0.8518 - val_loss: 0.2972 - val_accuracy: 0.8500
# Epoch 966/1000
# 35/35 [==============================] - 1s 19ms/step - loss: 0.3153 - accuracy: 0.8313 - val_loss: 0.2805 - val_accuracy: 0.8964
# Epoch 967/1000
# 35/35 [==============================] - 1s 24ms/step - loss: 0.2984 - accuracy: 0.8571 - val_loss: 0.2810 - val_accuracy: 0.8750
# Epoch 968/1000
# 35/35 [==============================] - 1s 21ms/step - loss: 0.3153 - accuracy: 0.8562 - val_loss: 0.2837 - val_accuracy: 0.9286
# Epoch 969/1000
# 35/35 [==============================] - 1s 19ms/step - loss: 0.3018 - accuracy: 0.8554 - val_loss: 0.2832 - val_accuracy: 0.8679
# Epoch 970/1000
# 35/35 [==============================] - 1s 20ms/step - loss: 0.2956 - accuracy: 0.8625 - val_loss: 0.2716 - val_accuracy: 0.9107
# Epoch 971/1000
# 35/35 [==============================] - 1s 21ms/step - loss: 0.3006 - accuracy: 0.8598 - val_loss: 0.2923 - val_accuracy: 0.8786
# Epoch 972/1000
# 35/35 [==============================] - 1s 22ms/step - loss: 0.3046 - accuracy: 0.8438 - val_loss: 0.2671 - val_accuracy: 0.9036
# Epoch 973/1000
# 35/35 [==============================] - 1s 19ms/step - loss: 0.3016 - accuracy: 0.8545 - val_loss: 0.2733 - val_accuracy: 0.8857
# Epoch 974/1000
# 35/35 [==============================] - 1s 17ms/step - loss: 0.3097 - accuracy: 0.8438 - val_loss: 0.2903 - val_accuracy: 0.8571
# Epoch 975/1000
# 35/35 [==============================] - 1s 15ms/step - loss: 0.3007 - accuracy: 0.8616 - val_loss: 0.2765 - val_accuracy: 0.8929
# Epoch 976/1000
# 35/35 [==============================] - 1s 19ms/step - loss: 0.3193 - accuracy: 0.8429 - val_loss: 0.2875 - val_accuracy: 0.8821
# Epoch 977/1000
# 35/35 [==============================] - 1s 17ms/step - loss: 0.3131 - accuracy: 0.8429 - val_loss: 0.3014 - val_accuracy: 0.8750
# Epoch 978/1000
# 35/35 [==============================] - 1s 16ms/step - loss: 0.3039 - accuracy: 0.8580 - val_loss: 0.2687 - val_accuracy: 0.8929
# Epoch 979/1000
# 35/35 [==============================] - 1s 17ms/step - loss: 0.3037 - accuracy: 0.8518 - val_loss: 0.2726 - val_accuracy: 0.8964
# Epoch 980/1000
# 35/35 [==============================] - 1s 18ms/step - loss: 0.2992 - accuracy: 0.8625 - val_loss: 0.2837 - val_accuracy: 0.9250
# Epoch 981/1000
# 35/35 [==============================] - 1s 21ms/step - loss: 0.3047 - accuracy: 0.8580 - val_loss: 0.2784 - val_accuracy: 0.8929
# Epoch 982/1000
# 35/35 [==============================] - 1s 18ms/step - loss: 0.3262 - accuracy: 0.8455 - val_loss: 0.2941 - val_accuracy: 0.8643
# Epoch 983/1000
# 35/35 [==============================] - 1s 22ms/step - loss: 0.3152 - accuracy: 0.8411 - val_loss: 0.2705 - val_accuracy: 0.9107
# Epoch 984/1000
# 35/35 [==============================] - 1s 16ms/step - loss: 0.2979 - accuracy: 0.8705 - val_loss: 0.2769 - val_accuracy: 0.9036
# Epoch 985/1000
# 35/35 [==============================] - 0s 14ms/step - loss: 0.3042 - accuracy: 0.8625 - val_loss: 0.2809 - val_accuracy: 0.8714
# Epoch 986/1000
# 35/35 [==============================] - 1s 21ms/step - loss: 0.3147 - accuracy: 0.8571 - val_loss: 0.2712 - val_accuracy: 0.9071
# Epoch 987/1000
# 35/35 [==============================] - 1s 14ms/step - loss: 0.3009 - accuracy: 0.8536 - val_loss: 0.3054 - val_accuracy: 0.8500
# Epoch 988/1000
# 35/35 [==============================] - 1s 16ms/step - loss: 0.3184 - accuracy: 0.8402 - val_loss: 0.2908 - val_accuracy: 0.8821
# Epoch 989/1000
# 35/35 [==============================] - 1s 15ms/step - loss: 0.3057 - accuracy: 0.8661 - val_loss: 0.2796 - val_accuracy: 0.8786
# Epoch 990/1000
# 35/35 [==============================] - 1s 17ms/step - loss: 0.2913 - accuracy: 0.8687 - val_loss: 0.2738 - val_accuracy: 0.8750
# Epoch 991/1000
# 35/35 [==============================] - 1s 17ms/step - loss: 0.2999 - accuracy: 0.8598 - val_loss: 0.3038 - val_accuracy: 0.8571
# Epoch 992/1000
# 35/35 [==============================] - 1s 15ms/step - loss: 0.2995 - accuracy: 0.8554 - val_loss: 0.2819 - val_accuracy: 0.8893
# Epoch 993/1000
# 35/35 [==============================] - 1s 20ms/step - loss: 0.3221 - accuracy: 0.8411 - val_loss: 0.2734 - val_accuracy: 0.8786
# Epoch 994/1000
# 35/35 [==============================] - 1s 23ms/step - loss: 0.3094 - accuracy: 0.8446 - val_loss: 0.3102 - val_accuracy: 0.8571
# Epoch 995/1000
# 35/35 [==============================] - 1s 19ms/step - loss: 0.2956 - accuracy: 0.8687 - val_loss: 0.2837 - val_accuracy: 0.8964
# Epoch 996/1000
# 35/35 [==============================] - 1s 19ms/step - loss: 0.2952 - accuracy: 0.8643 - val_loss: 0.2701 - val_accuracy: 0.8643
# Epoch 997/1000
# 35/35 [==============================] - 1s 18ms/step - loss: 0.2908 - accuracy: 0.8696 - val_loss: 0.2806 - val_accuracy: 0.8750
# Epoch 998/1000
# 35/35 [==============================] - 1s 20ms/step - loss: 0.3038 - accuracy: 0.8670 - val_loss: 0.2738 - val_accuracy: 0.8750
# Epoch 999/1000
# 35/35 [==============================] - 1s 15ms/step - loss: 0.3061 - accuracy: 0.8589 - val_loss: 0.2893 - val_accuracy: 0.8893
# Epoch 1000/1000
# 35/35 [==============================] - 1s 16ms/step - loss: 0.3046 - accuracy: 0.8571 - val_loss: 0.2775 - val_accuracy: 0.8714

# %%
#-----------------------------------------------------------------------------------------------------------
#Plot the architecture (with netron)
#-----------------------------------------------------------------------------------------------------------
from tensorflow.keras.utils import plot_model
import pydot
#for this to work pip install pydot
#install graphviz.exe for windows: https://graphviz.gitlab.io/download/

#Save the model:
#model.save('./figures%s/Planck_NN_model.h5' %PS)

import netron
#netron.start('./figures%s/Planck_NN_model.h5' %PS)

# %% [markdown]
# ### Learning curves visualization

# %%
#-----------------------------------------------------------------------------------------------------------
#Accuracy plot
#-----------------------------------------------------------------------------------------------------------
fig = plt.figure(figsize=(8,6))
plt.plot(History.history['accuracy'])
plt.plot(History.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='lower right')
plt.grid(color='lightgray', linestyle='--')
plt.show()

# %%
#-----------------------------------------------------------------------------------------------------------
#Loss plot
#-----------------------------------------------------------------------------------------------------------
fig = plt.figure(figsize=(8,6))
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.grid(color='lightgray', linestyle='--')
plt.show()

# %% [markdown]
# ### Testing the NNs

# %%
#Function for the probability of classification as LCDM 
def normMoG(p):
  if 0<p<0.5:
    rr=1-p
  else:
    rr=p
  return rr

#Function for the probability of classification as MoG 
def normLCDM(p):
  if 0<p<0.5:
    rr=p
  else:
    rr=1-p
  return rr

# %%
#-----------------------------------------------------------------------------------------------------------
#Test the NN
#-----------------------------------------------------------------------------------------------------------
theory = ['LCDM','MoG']

true_model=[]
pred_model=[]
prob_pred_MoG=[]
prob_pred_LCDM=[]
for i in range(len(X_test)):
  X_test_tf = tf.convert_to_tensor([X_test[i]])
  predictions = model.predict(X_test_tf)
  true_model.append(round(y_test[i]))
  pred_model.append(round(predictions[0][0]))
  prob_pred_MoG.append(round(100*normMoG(predictions[0][0]),3))
  prob_pred_LCDM.append(round(100*normLCDM(predictions[0][0]),3))
# Out:
# 1/1 [==============================] - 1s 549ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 279ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 351ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 393ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 0s 239ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 288ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 361ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 237ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 284ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 434ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 255ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step

# %% [markdown]
# ### Performance verification of the NNs

# %%
#-----------------------------------------------------------------------------------------------------------
#Performance: correct & incorrect  predictions
#-----------------------------------------------------------------------------------------------------------
true_LCDM = []
true_MoG = []
false_LCDM = []
false_MoG = []

for pred, true in zip(pred_model, true_model):
    if pred==0 and true==0:
        true_LCDM.append(1)
    if pred==1 and true==1:
        true_MoG.append(1)
    if pred==0 and true==1:
        false_LCDM.append(1)
    if pred==1 and true==0:
        false_MoG.append(1)
lenghts=[len(true_LCDM),len(true_MoG),len(false_LCDM),len(false_MoG)]

print('     ','LCDM','MoG')
print('True ',len(true_LCDM)/sum(lenghts),len(true_MoG)/sum(lenghts))
print('False',len(false_LCDM)/sum(lenghts),len(false_MoG)/sum(lenghts))
print('--------------')
print("Correct prediction: ",(len(true_LCDM)+len(true_MoG))/sum(lenghts))
print("Wrong prediction  : ",(len(false_LCDM)+len(false_MoG))/sum(lenghts))
# Out:
#       LCDM MoG
# True  0.5033333333333333 0.38166666666666665
# False 0.115 0.0
# --------------
# Correct prediction:  0.885
# Wrong prediction  :  0.115

# %%
#-----------------------------------------------------------------------------------------------------------
#Probability distribution of classification as MoG
#-----------------------------------------------------------------------------------------------------------
fig = plt.figure(figsize=(8,6))
plt.hist(prob_pred_MoG, label='MoG', alpha=0.6, color='#FF7F0E')
plt.xlabel('Predicted probability')
plt.ylabel('Number of samples')
plt.legend()
plt.show()

# %%
#-----------------------------------------------------------------------------------------------------------
#Probability distribution of classification as LCDM
#-----------------------------------------------------------------------------------------------------------
fig = plt.figure(figsize=(8,6))
plt.hist(prob_pred_LCDM, label='$\Lambda$CDM', alpha=0.6)
plt.xlabel('Predicted probability')
plt.ylabel('Number of samples')
plt.legend()
plt.show()

# %%
#-----------------------------------------------------------------------------------------------------------
##Confusion matrix
#-----------------------------------------------------------------------------------------------------------
from sklearn import metrics
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap

fsize=18
cm = metrics.confusion_matrix(true_model, pred_model)

#Create normalized Confusion Matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

colors = ["white", "brown"]
cmap = LinearSegmentedColormap.from_list("gray_to_red", colors)

heatmap = sns.heatmap(cm_normalized, 
            annot=True, 
            annot_kws={"size": fsize},
            linewidths=0.01,
            fmt=".2f", 
            xticklabels=['$\Lambda$CDM', 'HS'],
            yticklabels=['$\Lambda$CDM', 'HS'], cmap=cmap)
plt.xlabel('Predicted Class', fontsize=fsize, labelpad=15)
plt.ylabel('True Class', fontsize=fsize, labelpad=15)

plt.xticks(fontsize=fsize)
plt.yticks(fontsize=fsize)

num_ticks = 2  
x_ticks = np.array([0, 1])
colorbar = heatmap.collections[0].colorbar
colorbar.ax.set_yticks(np.linspace(0, 1, num_ticks))
colorbar.ax.set_yticklabels(x_ticks, fontsize=fsize)

plt.title('$\;$\n\n$C_{\ell}^{TT} + C_{\ell}^{TE} +C_{\ell}^{EE}$', fontsize=20)
plt.tight_layout()
plt.savefig('./figures_MoG/conf_matrix_%s.pdf' %J)
plt.show()
