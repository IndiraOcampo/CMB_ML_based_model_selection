# %% [markdown]
# # **Neural Networks for model selection, $\mathcal{C}^{EE}_{\ell}$ data**
# ## Primordial Feature template vs ΛCDM
# Can the NN differentiate a primoridal feature template and the ΛCDM models at the level of the CMB angular power spectrum?

# %%
#Import packages
import pandas as pd
import numpy as np
import math
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.layers.experimental.preprocessing import Normalization
from matplotlib import pyplot as plt
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ### Read and visualize the data (simulated out of [CLASS](https://github.com/lesgourg/class_public) and the [ESA Planck Archival](https://pla.esac.esa.int/#home))

# %%
#Read the data
PS = '_EEcls'
label_Ax0 = 'Ax_e-2'
planck_df_LCDM = np.genfromtxt('./simulated_data/EE_polarization/clsEE_LCDM_noisy.csv', delimiter=',')
planck_df_MoG = np.genfromtxt('./simulated_data/EE_polarization/clsEE_Feature_noisy%s.csv'%label_Ax0, delimiter=',')
planck_cls_LCDM = planck_df_LCDM[1:] # get rid of the first column, i.e. multipole moment l
planck_cls_MoG = planck_df_MoG[1:]
ls = planck_df_LCDM[0]

#Add the model class: 
LCDM_class = np.zeros(len(planck_cls_LCDM))
MoG_class = np.ones(len(planck_cls_MoG))

#Full arrays (+target):
cls_LCDM_class = np.column_stack((planck_cls_LCDM, LCDM_class))
cls_MoG_class = np.column_stack((planck_cls_MoG, MoG_class))

#Full data set (LCDM + MoG)
cls_full_dataset = np.concatenate((planck_cls_LCDM, planck_cls_MoG)) #without the class: x_dataset
dataset_class = np.concatenate((LCDM_class, MoG_class)) #only the class: y_dataset
cls_full_dataset_class = np.concatenate((cls_LCDM_class, cls_MoG_class)) #with the class: xy_dataset

# %%
#Plot the differences LCDM - MoG
plt.plot(ls,planck_cls_LCDM[0]-planck_cls_MoG[0])
plt.xlabel('Multipole moment ${\ell}$')
plt.ylabel('$\mathcal{C}^{EE}_{\ell}(\Lambda CDM)$ - $\mathcal{C}^{EE}_{\ell} (Feature)$')
# Out:
# Text(0, 0.5, '$\\mathcal{C}^{EE}_{\\ell}(\\Lambda CDM)$ - $\\mathcal{C}^{EE}_{\\ell} (Feature)$')

# %% [markdown]
# ## Angular power spectrum (EE component)

# %%
#-----------------------------------------------------------------------------------------------------------------------
#Plot Cls
#-----------------------------------------------------------------------------------------------------------------------
fig = plt.figure(figsize=(8,6))
plt.scatter(ls,cls_full_dataset[50:][0], label='$\Lambda$CDM', marker='o', s=8)
plt.scatter(ls,cls_full_dataset[50:][249], label='Feature', marker='o', s=8)
plt.xlabel('${\ell}$')
plt.ylabel('$\mathcal{C}^{EE}_{\ell}$')
plt.legend()
plt.grid(color='lightgray', linestyle='--')

# %%
#-----------------------------------------------------------------------------------------------------------------------
#Plot Dls
#-----------------------------------------------------------------------------------------------------------------------
# Create a function for converting the C_ls^EE to Dls Tcmb=2.7255
def Dls(l,CEE):
    Dl = [l[i]*(l[i]+1)*CEE[i]/((2*math.pi)*(2.7255*10**6)**2) for i in range(len(l))]
    return Dl
#-----------------------------------------------------------------------------------------------------------------------
fig = plt.figure(figsize=(8,6))
plt.plot(ls,Dls(ls,cls_full_dataset[:50][0]), label='$\Lambda$CDM')
plt.plot(ls,Dls(ls,cls_full_dataset[50:][249]), label='Feature')
plt.xlabel('${\ell}$')
plt.ylabel('$\mathcal{D}^{EE}_{\ell}$')
plt.legend()
plt.grid(color='lightgray', linestyle='--')

# %% [markdown]
# ### Z-score normalization of the $\mathcal{C}^{EE}_{\ell}$ data

# %%
#-------------------------------------------------------------------------------------------------------------
#Normalization and visualization
#-------------------------------------------------------------------------------------------------------------
fig = plt.figure(figsize=(8,6))
normalize = Normalization()
normalize.adapt(cls_full_dataset)
normalized_data = normalize(cls_full_dataset)
plt.scatter(ls,normalized_data[0], label='$\Lambda$CDM', marker='o', s=8)
plt.scatter(ls,normalized_data[-1], label='Feature', marker='o', s=8)
plt.grid(color='lightgray', linestyle='--')
plt.legend()
plt.xlabel('${\ell}$')
plt.ylabel('Normalized $\mathcal{C}^{EE}_{\ell}$')
# Out:
# Text(0, 0.5, 'Normalized $\\mathcal{C}^{EE}_{\\ell}$')

# %%
#Z-SCORE verification
print('var: %.4f' % np.var(normalized_data))
print('mean: %.4f' % np.mean(normalized_data))
# Out:
# var: 1.0000
# mean: 0.0000

# %% [markdown]
# ### Training the neural networks

# %%
#Train_test_split
from sklearn.model_selection import train_test_split
normalized_data_numpy = normalized_data.numpy()
X_train, X_test, y_train, y_test = train_test_split(normalized_data_numpy, dataset_class, test_size=0.3, random_state=42)
#Training and validation split with fixed random seed
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
#Redefine the model's architecture to display the input layer: (functional API)
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout

inputs = Input(shape=(len(normalized_data[0]),), name='input_layer') #shape=X_train.shape[1],
hidden_layer = Dense(32, activation='relu', name='hidden_layer')(inputs)
dropout_layer = Dropout(rate=0.2, name='dropout_layer')(hidden_layer)
outputs = Dense(1, activation='sigmoid', name='output_layer')(dropout_layer)

#Create the model
model = Model(inputs=inputs, outputs=outputs, name='Angular_PS_NN')

#Model details
model.summary()
# Out:
# Model: "Angular_PS_NN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 66)]              0
#
#  hidden_layer (Dense)        (None, 32)                2144
#
#  dropout_layer (Dropout)     (None, 32)                0
#
#  output_layer (Dense)        (None, 1)                 33
#
# =================================================================
# Total params: 2177 (8.50 KB)
# Trainable params: 2177 (8.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#-----------------------------------------------------------------------------------------------------------
#Training the NN
#-----------------------------------------------------------------------------------------------------------
model.reset_states()
#Compile model:
model.compile(optimizer=Adam(learning_rate=0.0002), loss='binary_crossentropy', metrics=['accuracy'])

#Training:
History = model.fit(X_train, y_train, epochs=1000, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Epoch 1/1000
# 18/18 [==============================] - 1s 14ms/step - loss: 0.8039 - accuracy: 0.4732 - val_loss: 0.7460 - val_accuracy: 0.4429
# Epoch 2/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.7664 - accuracy: 0.4964 - val_loss: 0.7195 - val_accuracy: 0.4214
# Epoch 3/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.7388 - accuracy: 0.5018 - val_loss: 0.6972 - val_accuracy: 0.4429
# Epoch 4/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.7148 - accuracy: 0.5304 - val_loss: 0.6772 - val_accuracy: 0.4857
# Epoch 5/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6863 - accuracy: 0.5375 - val_loss: 0.6585 - val_accuracy: 0.5357
# Epoch 6/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6905 - accuracy: 0.5464 - val_loss: 0.6397 - val_accuracy: 0.5643
# Epoch 7/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6595 - accuracy: 0.6036 - val_loss: 0.6217 - val_accuracy: 0.6500
# Epoch 8/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6334 - accuracy: 0.6321 - val_loss: 0.6073 - val_accuracy: 0.6786
# Epoch 9/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6272 - accuracy: 0.6411 - val_loss: 0.5913 - val_accuracy: 0.7643
# Epoch 10/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6211 - accuracy: 0.6536 - val_loss: 0.5744 - val_accuracy: 0.8286
# Epoch 11/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6011 - accuracy: 0.7018 - val_loss: 0.5614 - val_accuracy: 0.8500
# Epoch 12/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5847 - accuracy: 0.7286 - val_loss: 0.5463 - val_accuracy: 0.8929
# Epoch 13/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5733 - accuracy: 0.7554 - val_loss: 0.5335 - val_accuracy: 0.9214
# Epoch 14/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5602 - accuracy: 0.7607 - val_loss: 0.5198 - val_accuracy: 0.9357
# Epoch 15/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5301 - accuracy: 0.8179 - val_loss: 0.5068 - val_accuracy: 0.9357
# Epoch 16/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5231 - accuracy: 0.8125 - val_loss: 0.4956 - val_accuracy: 0.9429
# Epoch 17/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5081 - accuracy: 0.8250 - val_loss: 0.4840 - val_accuracy: 0.9357
# Epoch 18/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5144 - accuracy: 0.8054 - val_loss: 0.4730 - val_accuracy: 0.9357
# Epoch 19/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4885 - accuracy: 0.8375 - val_loss: 0.4627 - val_accuracy: 0.9357
# Epoch 20/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4946 - accuracy: 0.8036 - val_loss: 0.4524 - val_accuracy: 0.9357
# Epoch 21/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4833 - accuracy: 0.8286 - val_loss: 0.4422 - val_accuracy: 0.9357
# Epoch 22/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4699 - accuracy: 0.8446 - val_loss: 0.4316 - val_accuracy: 0.9286
# Epoch 23/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4512 - accuracy: 0.8571 - val_loss: 0.4213 - val_accuracy: 0.9286
# Epoch 24/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4631 - accuracy: 0.8268 - val_loss: 0.4125 - val_accuracy: 0.9286
# Epoch 25/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4299 - accuracy: 0.8589 - val_loss: 0.4047 - val_accuracy: 0.9286
# Epoch 26/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4165 - accuracy: 0.8679 - val_loss: 0.3971 - val_accuracy: 0.9286
# Epoch 27/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4166 - accuracy: 0.8839 - val_loss: 0.3900 - val_accuracy: 0.9429
# Epoch 28/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4091 - accuracy: 0.8875 - val_loss: 0.3823 - val_accuracy: 0.9286
# Epoch 29/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3940 - accuracy: 0.8893 - val_loss: 0.3740 - val_accuracy: 0.9286
# Epoch 30/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3911 - accuracy: 0.9018 - val_loss: 0.3664 - val_accuracy: 0.9286
# Epoch 31/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3804 - accuracy: 0.8911 - val_loss: 0.3609 - val_accuracy: 0.9286
# Epoch 32/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3870 - accuracy: 0.8768 - val_loss: 0.3529 - val_accuracy: 0.9286
# Epoch 33/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3724 - accuracy: 0.8911 - val_loss: 0.3465 - val_accuracy: 0.9429
# Epoch 34/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3622 - accuracy: 0.8946 - val_loss: 0.3394 - val_accuracy: 0.9214
# Epoch 35/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3616 - accuracy: 0.8911 - val_loss: 0.3340 - val_accuracy: 0.9286
# Epoch 36/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3548 - accuracy: 0.8911 - val_loss: 0.3283 - val_accuracy: 0.9286
# Epoch 37/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3373 - accuracy: 0.9000 - val_loss: 0.3225 - val_accuracy: 0.9286
# Epoch 38/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3408 - accuracy: 0.9143 - val_loss: 0.3168 - val_accuracy: 0.9357
# Epoch 39/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3294 - accuracy: 0.9107 - val_loss: 0.3108 - val_accuracy: 0.9286
# Epoch 40/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3368 - accuracy: 0.8821 - val_loss: 0.3069 - val_accuracy: 0.9286
# Epoch 41/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3283 - accuracy: 0.9018 - val_loss: 0.2999 - val_accuracy: 0.9286
# Epoch 42/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3110 - accuracy: 0.9036 - val_loss: 0.2956 - val_accuracy: 0.9357
# Epoch 43/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3159 - accuracy: 0.9054 - val_loss: 0.2907 - val_accuracy: 0.9357
# Epoch 44/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3142 - accuracy: 0.8982 - val_loss: 0.2866 - val_accuracy: 0.9357
# Epoch 45/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2919 - accuracy: 0.9196 - val_loss: 0.2819 - val_accuracy: 0.9357
# Epoch 46/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2975 - accuracy: 0.9232 - val_loss: 0.2776 - val_accuracy: 0.9357
# Epoch 47/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.2962 - accuracy: 0.9214 - val_loss: 0.2732 - val_accuracy: 0.9357
# Epoch 48/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2842 - accuracy: 0.9214 - val_loss: 0.2692 - val_accuracy: 0.9286
# Epoch 49/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2804 - accuracy: 0.9161 - val_loss: 0.2656 - val_accuracy: 0.9357
# Epoch 50/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2838 - accuracy: 0.9179 - val_loss: 0.2601 - val_accuracy: 0.9357
# Epoch 51/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2708 - accuracy: 0.9143 - val_loss: 0.2558 - val_accuracy: 0.9357
# Epoch 52/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2754 - accuracy: 0.9179 - val_loss: 0.2519 - val_accuracy: 0.9286
# Epoch 53/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2784 - accuracy: 0.9143 - val_loss: 0.2483 - val_accuracy: 0.9286
# Epoch 54/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2665 - accuracy: 0.9143 - val_loss: 0.2439 - val_accuracy: 0.9214
# Epoch 55/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2618 - accuracy: 0.9232 - val_loss: 0.2402 - val_accuracy: 0.9357
# Epoch 56/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2588 - accuracy: 0.9089 - val_loss: 0.2375 - val_accuracy: 0.9286
# Epoch 57/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2489 - accuracy: 0.9286 - val_loss: 0.2339 - val_accuracy: 0.9357
# Epoch 58/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2456 - accuracy: 0.9250 - val_loss: 0.2297 - val_accuracy: 0.9357
# Epoch 59/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2460 - accuracy: 0.9286 - val_loss: 0.2276 - val_accuracy: 0.9286
# Epoch 60/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2429 - accuracy: 0.9196 - val_loss: 0.2248 - val_accuracy: 0.9429
# Epoch 61/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2424 - accuracy: 0.9286 - val_loss: 0.2207 - val_accuracy: 0.9429
# Epoch 62/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2379 - accuracy: 0.9250 - val_loss: 0.2168 - val_accuracy: 0.9357
# Epoch 63/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2347 - accuracy: 0.9339 - val_loss: 0.2146 - val_accuracy: 0.9429
# Epoch 64/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2273 - accuracy: 0.9268 - val_loss: 0.2114 - val_accuracy: 0.9429
# Epoch 65/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2231 - accuracy: 0.9286 - val_loss: 0.2087 - val_accuracy: 0.9429
# Epoch 66/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2261 - accuracy: 0.9357 - val_loss: 0.2058 - val_accuracy: 0.9429
# Epoch 67/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2230 - accuracy: 0.9286 - val_loss: 0.2031 - val_accuracy: 0.9429
# Epoch 68/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2200 - accuracy: 0.9357 - val_loss: 0.2002 - val_accuracy: 0.9429
# Epoch 69/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2160 - accuracy: 0.9339 - val_loss: 0.1980 - val_accuracy: 0.9500
# Epoch 70/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2119 - accuracy: 0.9357 - val_loss: 0.1953 - val_accuracy: 0.9429
# Epoch 71/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2132 - accuracy: 0.9357 - val_loss: 0.1926 - val_accuracy: 0.9429
# Epoch 72/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2104 - accuracy: 0.9393 - val_loss: 0.1903 - val_accuracy: 0.9429
# Epoch 73/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2102 - accuracy: 0.9393 - val_loss: 0.1883 - val_accuracy: 0.9429
# Epoch 74/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2078 - accuracy: 0.9232 - val_loss: 0.1861 - val_accuracy: 0.9429
# Epoch 75/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1928 - accuracy: 0.9482 - val_loss: 0.1853 - val_accuracy: 0.9500
# Epoch 76/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2054 - accuracy: 0.9393 - val_loss: 0.1830 - val_accuracy: 0.9500
# Epoch 77/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1964 - accuracy: 0.9464 - val_loss: 0.1800 - val_accuracy: 0.9500
# Epoch 78/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1942 - accuracy: 0.9500 - val_loss: 0.1772 - val_accuracy: 0.9500
# Epoch 79/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1833 - accuracy: 0.9589 - val_loss: 0.1747 - val_accuracy: 0.9500
# Epoch 80/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1931 - accuracy: 0.9536 - val_loss: 0.1729 - val_accuracy: 0.9500
# Epoch 81/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.1925 - accuracy: 0.9482 - val_loss: 0.1711 - val_accuracy: 0.9500
# Epoch 82/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1853 - accuracy: 0.9429 - val_loss: 0.1688 - val_accuracy: 0.9571
# Epoch 83/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.1865 - accuracy: 0.9571 - val_loss: 0.1671 - val_accuracy: 0.9571
# Epoch 84/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1765 - accuracy: 0.9661 - val_loss: 0.1649 - val_accuracy: 0.9571
# Epoch 85/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1835 - accuracy: 0.9446 - val_loss: 0.1622 - val_accuracy: 0.9571
# Epoch 86/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1741 - accuracy: 0.9464 - val_loss: 0.1594 - val_accuracy: 0.9500
# Epoch 87/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1752 - accuracy: 0.9536 - val_loss: 0.1580 - val_accuracy: 0.9571
# Epoch 88/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1731 - accuracy: 0.9518 - val_loss: 0.1561 - val_accuracy: 0.9643
# Epoch 89/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1650 - accuracy: 0.9661 - val_loss: 0.1541 - val_accuracy: 0.9500
# Epoch 90/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1679 - accuracy: 0.9536 - val_loss: 0.1526 - val_accuracy: 0.9500
# Epoch 91/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1694 - accuracy: 0.9464 - val_loss: 0.1516 - val_accuracy: 0.9571
# Epoch 92/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1671 - accuracy: 0.9571 - val_loss: 0.1494 - val_accuracy: 0.9643
# Epoch 93/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1608 - accuracy: 0.9589 - val_loss: 0.1472 - val_accuracy: 0.9643
# Epoch 94/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1701 - accuracy: 0.9464 - val_loss: 0.1458 - val_accuracy: 0.9643
# Epoch 95/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1624 - accuracy: 0.9643 - val_loss: 0.1439 - val_accuracy: 0.9571
# Epoch 96/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1572 - accuracy: 0.9625 - val_loss: 0.1426 - val_accuracy: 0.9714
# Epoch 97/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1594 - accuracy: 0.9661 - val_loss: 0.1400 - val_accuracy: 0.9643
# Epoch 98/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1533 - accuracy: 0.9643 - val_loss: 0.1388 - val_accuracy: 0.9714
# Epoch 99/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1492 - accuracy: 0.9750 - val_loss: 0.1369 - val_accuracy: 0.9714
# Epoch 100/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1488 - accuracy: 0.9643 - val_loss: 0.1349 - val_accuracy: 0.9643
# Epoch 101/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1488 - accuracy: 0.9625 - val_loss: 0.1337 - val_accuracy: 0.9714
# Epoch 102/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.1452 - accuracy: 0.9661 - val_loss: 0.1323 - val_accuracy: 0.9714
# Epoch 103/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1476 - accuracy: 0.9750 - val_loss: 0.1307 - val_accuracy: 0.9714
# Epoch 104/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1503 - accuracy: 0.9661 - val_loss: 0.1294 - val_accuracy: 0.9714
# Epoch 105/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1377 - accuracy: 0.9714 - val_loss: 0.1281 - val_accuracy: 0.9714
# Epoch 106/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1457 - accuracy: 0.9643 - val_loss: 0.1268 - val_accuracy: 0.9786
# Epoch 107/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1384 - accuracy: 0.9714 - val_loss: 0.1252 - val_accuracy: 0.9786
# Epoch 108/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1353 - accuracy: 0.9643 - val_loss: 0.1240 - val_accuracy: 0.9786
# Epoch 109/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1395 - accuracy: 0.9750 - val_loss: 0.1226 - val_accuracy: 0.9786
# Epoch 110/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1409 - accuracy: 0.9625 - val_loss: 0.1205 - val_accuracy: 0.9857
# Epoch 111/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1384 - accuracy: 0.9661 - val_loss: 0.1195 - val_accuracy: 0.9786
# Epoch 112/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1419 - accuracy: 0.9714 - val_loss: 0.1181 - val_accuracy: 0.9857
# Epoch 113/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1279 - accuracy: 0.9768 - val_loss: 0.1164 - val_accuracy: 0.9857
# Epoch 114/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1305 - accuracy: 0.9732 - val_loss: 0.1150 - val_accuracy: 0.9786
# Epoch 115/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1350 - accuracy: 0.9625 - val_loss: 0.1136 - val_accuracy: 0.9857
# Epoch 116/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1313 - accuracy: 0.9607 - val_loss: 0.1124 - val_accuracy: 0.9786
# Epoch 117/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1292 - accuracy: 0.9750 - val_loss: 0.1109 - val_accuracy: 0.9857
# Epoch 118/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1240 - accuracy: 0.9857 - val_loss: 0.1101 - val_accuracy: 0.9857
# Epoch 119/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1231 - accuracy: 0.9804 - val_loss: 0.1087 - val_accuracy: 0.9857
# Epoch 120/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1237 - accuracy: 0.9750 - val_loss: 0.1077 - val_accuracy: 0.9857
# Epoch 121/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1206 - accuracy: 0.9839 - val_loss: 0.1062 - val_accuracy: 0.9857
# Epoch 122/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1291 - accuracy: 0.9768 - val_loss: 0.1050 - val_accuracy: 0.9857
# Epoch 123/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1187 - accuracy: 0.9786 - val_loss: 0.1033 - val_accuracy: 0.9857
# Epoch 124/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1211 - accuracy: 0.9821 - val_loss: 0.1025 - val_accuracy: 0.9857
# Epoch 125/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1259 - accuracy: 0.9732 - val_loss: 0.1016 - val_accuracy: 0.9857
# Epoch 126/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1158 - accuracy: 0.9839 - val_loss: 0.1001 - val_accuracy: 0.9857
# Epoch 127/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1191 - accuracy: 0.9768 - val_loss: 0.0988 - val_accuracy: 0.9857
# Epoch 128/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1159 - accuracy: 0.9768 - val_loss: 0.0975 - val_accuracy: 1.0000
# Epoch 129/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1105 - accuracy: 0.9875 - val_loss: 0.0967 - val_accuracy: 1.0000
# Epoch 130/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.1059 - accuracy: 0.9875 - val_loss: 0.0953 - val_accuracy: 1.0000
# Epoch 131/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1055 - accuracy: 0.9875 - val_loss: 0.0945 - val_accuracy: 1.0000
# Epoch 132/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1108 - accuracy: 0.9768 - val_loss: 0.0932 - val_accuracy: 1.0000
# Epoch 133/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1095 - accuracy: 0.9804 - val_loss: 0.0924 - val_accuracy: 1.0000
# Epoch 134/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1068 - accuracy: 0.9875 - val_loss: 0.0916 - val_accuracy: 1.0000
# Epoch 135/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1069 - accuracy: 0.9893 - val_loss: 0.0908 - val_accuracy: 0.9929
# Epoch 136/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1056 - accuracy: 0.9804 - val_loss: 0.0891 - val_accuracy: 0.9929
# Epoch 137/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1015 - accuracy: 0.9804 - val_loss: 0.0880 - val_accuracy: 1.0000
# Epoch 138/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1097 - accuracy: 0.9768 - val_loss: 0.0871 - val_accuracy: 1.0000
# Epoch 139/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1023 - accuracy: 0.9875 - val_loss: 0.0858 - val_accuracy: 1.0000
# Epoch 140/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1016 - accuracy: 0.9786 - val_loss: 0.0851 - val_accuracy: 1.0000
# Epoch 141/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1007 - accuracy: 0.9857 - val_loss: 0.0838 - val_accuracy: 1.0000
# Epoch 142/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0923 - accuracy: 0.9857 - val_loss: 0.0829 - val_accuracy: 1.0000
# Epoch 143/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0969 - accuracy: 0.9857 - val_loss: 0.0817 - val_accuracy: 1.0000
# Epoch 144/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0933 - accuracy: 0.9911 - val_loss: 0.0810 - val_accuracy: 1.0000
# Epoch 145/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0988 - accuracy: 0.9893 - val_loss: 0.0796 - val_accuracy: 1.0000
# Epoch 146/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0941 - accuracy: 0.9857 - val_loss: 0.0788 - val_accuracy: 1.0000
# Epoch 147/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0968 - accuracy: 0.9839 - val_loss: 0.0779 - val_accuracy: 1.0000
# Epoch 148/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0907 - accuracy: 0.9929 - val_loss: 0.0770 - val_accuracy: 1.0000
# Epoch 149/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0869 - accuracy: 0.9946 - val_loss: 0.0759 - val_accuracy: 1.0000
# Epoch 150/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0899 - accuracy: 0.9911 - val_loss: 0.0748 - val_accuracy: 1.0000
# Epoch 151/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0860 - accuracy: 0.9911 - val_loss: 0.0740 - val_accuracy: 1.0000
# Epoch 152/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0894 - accuracy: 0.9875 - val_loss: 0.0728 - val_accuracy: 1.0000
# Epoch 153/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0861 - accuracy: 0.9946 - val_loss: 0.0718 - val_accuracy: 1.0000
# Epoch 154/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0833 - accuracy: 0.9911 - val_loss: 0.0705 - val_accuracy: 1.0000
# Epoch 155/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0828 - accuracy: 0.9875 - val_loss: 0.0696 - val_accuracy: 1.0000
# Epoch 156/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0821 - accuracy: 0.9911 - val_loss: 0.0688 - val_accuracy: 1.0000
# Epoch 157/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0792 - accuracy: 0.9911 - val_loss: 0.0681 - val_accuracy: 1.0000
# Epoch 158/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0790 - accuracy: 0.9964 - val_loss: 0.0672 - val_accuracy: 1.0000
# Epoch 159/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0795 - accuracy: 0.9929 - val_loss: 0.0662 - val_accuracy: 1.0000
# Epoch 160/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0769 - accuracy: 0.9982 - val_loss: 0.0653 - val_accuracy: 1.0000
# Epoch 161/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0827 - accuracy: 0.9911 - val_loss: 0.0650 - val_accuracy: 1.0000
# Epoch 162/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0786 - accuracy: 0.9911 - val_loss: 0.0644 - val_accuracy: 1.0000
# Epoch 163/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0786 - accuracy: 0.9946 - val_loss: 0.0634 - val_accuracy: 1.0000
# Epoch 164/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0798 - accuracy: 0.9911 - val_loss: 0.0625 - val_accuracy: 1.0000
# Epoch 165/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0753 - accuracy: 0.9982 - val_loss: 0.0617 - val_accuracy: 1.0000
# Epoch 166/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0779 - accuracy: 0.9911 - val_loss: 0.0609 - val_accuracy: 1.0000
# Epoch 167/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0727 - accuracy: 0.9875 - val_loss: 0.0602 - val_accuracy: 1.0000
# Epoch 168/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0745 - accuracy: 0.9911 - val_loss: 0.0595 - val_accuracy: 1.0000
# Epoch 169/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0694 - accuracy: 0.9929 - val_loss: 0.0586 - val_accuracy: 1.0000
# Epoch 170/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0712 - accuracy: 0.9982 - val_loss: 0.0576 - val_accuracy: 1.0000
# Epoch 171/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0696 - accuracy: 0.9929 - val_loss: 0.0569 - val_accuracy: 1.0000
# Epoch 172/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0691 - accuracy: 0.9893 - val_loss: 0.0560 - val_accuracy: 1.0000
# Epoch 173/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0648 - accuracy: 0.9964 - val_loss: 0.0550 - val_accuracy: 1.0000
# Epoch 174/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0667 - accuracy: 0.9964 - val_loss: 0.0542 - val_accuracy: 1.0000
# Epoch 175/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0687 - accuracy: 0.9982 - val_loss: 0.0536 - val_accuracy: 1.0000
# Epoch 176/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0656 - accuracy: 1.0000 - val_loss: 0.0528 - val_accuracy: 1.0000
# Epoch 177/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0646 - accuracy: 0.9964 - val_loss: 0.0520 - val_accuracy: 1.0000
# Epoch 178/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0625 - accuracy: 0.9946 - val_loss: 0.0514 - val_accuracy: 1.0000
# Epoch 179/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0616 - accuracy: 1.0000 - val_loss: 0.0510 - val_accuracy: 1.0000
# Epoch 180/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0586 - accuracy: 0.9946 - val_loss: 0.0501 - val_accuracy: 1.0000
# Epoch 181/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0581 - accuracy: 0.9946 - val_loss: 0.0495 - val_accuracy: 1.0000
# Epoch 182/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0629 - accuracy: 0.9929 - val_loss: 0.0491 - val_accuracy: 1.0000
# Epoch 183/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0579 - accuracy: 0.9946 - val_loss: 0.0484 - val_accuracy: 1.0000
# Epoch 184/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0612 - accuracy: 0.9964 - val_loss: 0.0478 - val_accuracy: 1.0000
# Epoch 185/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0557 - accuracy: 0.9982 - val_loss: 0.0470 - val_accuracy: 1.0000
# Epoch 186/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0597 - accuracy: 0.9946 - val_loss: 0.0466 - val_accuracy: 1.0000
# Epoch 187/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0563 - accuracy: 0.9946 - val_loss: 0.0461 - val_accuracy: 1.0000
# Epoch 188/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0606 - accuracy: 0.9929 - val_loss: 0.0454 - val_accuracy: 1.0000
# Epoch 189/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0530 - accuracy: 1.0000 - val_loss: 0.0449 - val_accuracy: 1.0000
# Epoch 190/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0579 - accuracy: 0.9964 - val_loss: 0.0443 - val_accuracy: 1.0000
# Epoch 191/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0583 - accuracy: 0.9964 - val_loss: 0.0440 - val_accuracy: 1.0000
# Epoch 192/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0549 - accuracy: 0.9982 - val_loss: 0.0433 - val_accuracy: 1.0000
# Epoch 193/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0545 - accuracy: 0.9946 - val_loss: 0.0432 - val_accuracy: 1.0000
# Epoch 194/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0546 - accuracy: 0.9964 - val_loss: 0.0419 - val_accuracy: 1.0000
# Epoch 195/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0537 - accuracy: 0.9946 - val_loss: 0.0414 - val_accuracy: 1.0000
# Epoch 196/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0544 - accuracy: 0.9929 - val_loss: 0.0411 - val_accuracy: 1.0000
# Epoch 197/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0508 - accuracy: 0.9929 - val_loss: 0.0407 - val_accuracy: 1.0000
# Epoch 198/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0491 - accuracy: 0.9982 - val_loss: 0.0403 - val_accuracy: 1.0000
# Epoch 199/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0497 - accuracy: 0.9982 - val_loss: 0.0396 - val_accuracy: 1.0000
# Epoch 200/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0507 - accuracy: 0.9964 - val_loss: 0.0392 - val_accuracy: 1.0000
# Epoch 201/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0514 - accuracy: 0.9929 - val_loss: 0.0388 - val_accuracy: 1.0000
# Epoch 202/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0474 - accuracy: 0.9964 - val_loss: 0.0384 - val_accuracy: 1.0000
# Epoch 203/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0486 - accuracy: 0.9964 - val_loss: 0.0379 - val_accuracy: 1.0000
# Epoch 204/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0535 - accuracy: 0.9964 - val_loss: 0.0375 - val_accuracy: 1.0000
# Epoch 205/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0465 - accuracy: 0.9964 - val_loss: 0.0371 - val_accuracy: 1.0000
# Epoch 206/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0482 - accuracy: 0.9982 - val_loss: 0.0370 - val_accuracy: 1.0000
# Epoch 207/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0434 - accuracy: 0.9982 - val_loss: 0.0364 - val_accuracy: 1.0000
# Epoch 208/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0450 - accuracy: 1.0000 - val_loss: 0.0358 - val_accuracy: 1.0000
# Epoch 209/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0475 - accuracy: 0.9946 - val_loss: 0.0354 - val_accuracy: 1.0000
# Epoch 210/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0431 - accuracy: 0.9982 - val_loss: 0.0351 - val_accuracy: 1.0000
# Epoch 211/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0448 - accuracy: 0.9946 - val_loss: 0.0346 - val_accuracy: 1.0000
# Epoch 212/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0473 - accuracy: 0.9982 - val_loss: 0.0343 - val_accuracy: 1.0000
# Epoch 213/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0417 - accuracy: 0.9982 - val_loss: 0.0340 - val_accuracy: 1.0000
# Epoch 214/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0442 - accuracy: 0.9982 - val_loss: 0.0333 - val_accuracy: 1.0000
# Epoch 215/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 0.9982 - val_loss: 0.0329 - val_accuracy: 1.0000
# Epoch 216/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0454 - accuracy: 0.9964 - val_loss: 0.0326 - val_accuracy: 1.0000
# Epoch 217/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0442 - accuracy: 0.9964 - val_loss: 0.0322 - val_accuracy: 1.0000
# Epoch 218/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0433 - accuracy: 0.9964 - val_loss: 0.0318 - val_accuracy: 1.0000
# Epoch 219/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0394 - accuracy: 1.0000 - val_loss: 0.0313 - val_accuracy: 1.0000
# Epoch 220/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0401 - accuracy: 1.0000 - val_loss: 0.0309 - val_accuracy: 1.0000
# Epoch 221/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0417 - accuracy: 1.0000 - val_loss: 0.0307 - val_accuracy: 1.0000
# Epoch 222/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0403 - accuracy: 0.9964 - val_loss: 0.0305 - val_accuracy: 1.0000
# Epoch 223/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0402 - accuracy: 0.9982 - val_loss: 0.0300 - val_accuracy: 1.0000
# Epoch 224/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0353 - accuracy: 1.0000 - val_loss: 0.0296 - val_accuracy: 1.0000
# Epoch 225/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0359 - accuracy: 0.9982 - val_loss: 0.0293 - val_accuracy: 1.0000
# Epoch 226/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0401 - accuracy: 0.9964 - val_loss: 0.0288 - val_accuracy: 1.0000
# Epoch 227/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0347 - accuracy: 0.9964 - val_loss: 0.0288 - val_accuracy: 1.0000
# Epoch 228/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0343 - accuracy: 1.0000 - val_loss: 0.0282 - val_accuracy: 1.0000
# Epoch 229/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0379 - accuracy: 1.0000 - val_loss: 0.0278 - val_accuracy: 1.0000
# Epoch 230/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0389 - accuracy: 1.0000 - val_loss: 0.0277 - val_accuracy: 1.0000
# Epoch 231/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0377 - accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 1.0000
# Epoch 232/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0392 - accuracy: 0.9982 - val_loss: 0.0271 - val_accuracy: 1.0000
# Epoch 233/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0370 - accuracy: 1.0000 - val_loss: 0.0267 - val_accuracy: 1.0000
# Epoch 234/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0362 - accuracy: 0.9982 - val_loss: 0.0265 - val_accuracy: 1.0000
# Epoch 235/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0353 - accuracy: 0.9982 - val_loss: 0.0260 - val_accuracy: 1.0000
# Epoch 236/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0309 - accuracy: 1.0000 - val_loss: 0.0259 - val_accuracy: 1.0000
# Epoch 237/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0332 - accuracy: 1.0000 - val_loss: 0.0255 - val_accuracy: 1.0000
# Epoch 238/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0345 - accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 1.0000
# Epoch 239/1000
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0380 - accuracy: 0.9982 - val_loss: 0.0248 - val_accuracy: 1.0000
# Epoch 240/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0319 - accuracy: 1.0000 - val_loss: 0.0247 - val_accuracy: 1.0000
# Epoch 241/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0326 - accuracy: 0.9982 - val_loss: 0.0241 - val_accuracy: 1.0000
# Epoch 242/1000
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0305 - accuracy: 0.9982 - val_loss: 0.0238 - val_accuracy: 1.0000
# Epoch 243/1000
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0329 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 1.0000
# Epoch 244/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0306 - accuracy: 0.9982 - val_loss: 0.0233 - val_accuracy: 1.0000
# Epoch 245/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0345 - accuracy: 0.9946 - val_loss: 0.0229 - val_accuracy: 1.0000
# Epoch 246/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0297 - accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 1.0000
# Epoch 247/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0267 - accuracy: 0.9982 - val_loss: 0.0223 - val_accuracy: 1.0000
# Epoch 248/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0299 - accuracy: 1.0000 - val_loss: 0.0221 - val_accuracy: 1.0000
# Epoch 249/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0298 - accuracy: 1.0000 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 250/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0257 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 1.0000
# Epoch 251/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0279 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 1.0000
# Epoch 252/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0281 - accuracy: 0.9982 - val_loss: 0.0210 - val_accuracy: 1.0000
# Epoch 253/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 1.0000
# Epoch 254/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0277 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 1.0000
# Epoch 255/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0274 - accuracy: 0.9982 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 256/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0268 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 1.0000
# Epoch 257/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0261 - accuracy: 0.9982 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 258/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0272 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 1.0000
# Epoch 259/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 260/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0287 - accuracy: 1.0000 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 261/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0271 - accuracy: 1.0000 - val_loss: 0.0190 - val_accuracy: 1.0000
# Epoch 262/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0275 - accuracy: 0.9982 - val_loss: 0.0188 - val_accuracy: 1.0000
# Epoch 263/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0273 - accuracy: 0.9982 - val_loss: 0.0185 - val_accuracy: 1.0000
# Epoch 264/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0251 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 265/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0258 - accuracy: 0.9982 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 266/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0242 - accuracy: 1.0000 - val_loss: 0.0177 - val_accuracy: 1.0000
# Epoch 267/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0269 - accuracy: 0.9982 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 268/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 269/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0236 - accuracy: 1.0000 - val_loss: 0.0173 - val_accuracy: 1.0000
# Epoch 270/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0249 - accuracy: 1.0000 - val_loss: 0.0173 - val_accuracy: 1.0000
# Epoch 271/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0227 - accuracy: 1.0000 - val_loss: 0.0168 - val_accuracy: 1.0000
# Epoch 272/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0251 - accuracy: 1.0000 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 273/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0251 - accuracy: 0.9982 - val_loss: 0.0165 - val_accuracy: 1.0000
# Epoch 274/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0238 - accuracy: 1.0000 - val_loss: 0.0163 - val_accuracy: 1.0000
# Epoch 275/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0233 - accuracy: 0.9982 - val_loss: 0.0162 - val_accuracy: 1.0000
# Epoch 276/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0237 - accuracy: 0.9982 - val_loss: 0.0160 - val_accuracy: 1.0000
# Epoch 277/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0239 - accuracy: 1.0000 - val_loss: 0.0157 - val_accuracy: 1.0000
# Epoch 278/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0204 - accuracy: 0.9982 - val_loss: 0.0156 - val_accuracy: 1.0000
# Epoch 279/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0242 - accuracy: 1.0000 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 280/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0221 - accuracy: 1.0000 - val_loss: 0.0152 - val_accuracy: 1.0000
# Epoch 281/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 282/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0223 - accuracy: 0.9982 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 283/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 284/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0226 - accuracy: 0.9982 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 285/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0207 - accuracy: 0.9982 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 286/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0200 - accuracy: 0.9982 - val_loss: 0.0142 - val_accuracy: 1.0000
# Epoch 287/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0231 - accuracy: 1.0000 - val_loss: 0.0140 - val_accuracy: 1.0000
# Epoch 288/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.0139 - val_accuracy: 1.0000
# Epoch 289/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0247 - accuracy: 0.9964 - val_loss: 0.0137 - val_accuracy: 1.0000
# Epoch 290/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 291/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0179 - accuracy: 0.9982 - val_loss: 0.0134 - val_accuracy: 1.0000
# Epoch 292/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0174 - accuracy: 1.0000 - val_loss: 0.0134 - val_accuracy: 1.0000
# Epoch 293/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0206 - accuracy: 0.9982 - val_loss: 0.0131 - val_accuracy: 1.0000
# Epoch 294/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0183 - accuracy: 0.9982 - val_loss: 0.0131 - val_accuracy: 1.0000
# Epoch 295/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 296/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0213 - accuracy: 0.9982 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 297/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 298/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 299/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 300/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 1.0000
# Epoch 301/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.0119 - val_accuracy: 1.0000
# Epoch 302/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0184 - accuracy: 0.9982 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 303/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.0119 - val_accuracy: 1.0000
# Epoch 304/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 305/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 306/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 307/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 308/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 309/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 310/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 311/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.0107 - val_accuracy: 1.0000
# Epoch 312/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 313/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 1.0000
# Epoch 314/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 315/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 316/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0189 - accuracy: 0.9982 - val_loss: 0.0101 - val_accuracy: 1.0000
# Epoch 317/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 318/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0171 - accuracy: 0.9982 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 319/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0155 - accuracy: 0.9982 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 320/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 321/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9964 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 322/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 323/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 324/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 325/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 326/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 327/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 328/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 329/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 330/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0156 - accuracy: 0.9982 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 331/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 332/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 333/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 334/1000
# ...
# Epoch 896/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 2.1991e-04 - accuracy: 1.0000 - val_loss: 4.8359e-05 - val_accuracy: 1.0000
# Epoch 897/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.9264e-04 - accuracy: 1.0000 - val_loss: 4.6232e-05 - val_accuracy: 1.0000
# Epoch 898/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.2497e-04 - accuracy: 1.0000 - val_loss: 4.7118e-05 - val_accuracy: 1.0000
# Epoch 899/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 2.0385e-04 - accuracy: 1.0000 - val_loss: 4.7297e-05 - val_accuracy: 1.0000
# Epoch 900/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 2.5036e-04 - accuracy: 1.0000 - val_loss: 4.4572e-05 - val_accuracy: 1.0000
# Epoch 901/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.4099e-04 - accuracy: 1.0000 - val_loss: 4.4122e-05 - val_accuracy: 1.0000
# Epoch 902/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.9792e-04 - accuracy: 1.0000 - val_loss: 4.3369e-05 - val_accuracy: 1.0000
# Epoch 903/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 4.9296e-04 - accuracy: 1.0000 - val_loss: 4.6035e-05 - val_accuracy: 1.0000
# Epoch 904/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 3.5453e-04 - accuracy: 1.0000 - val_loss: 4.3662e-05 - val_accuracy: 1.0000
# Epoch 905/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 1.5487e-04 - accuracy: 1.0000 - val_loss: 4.2766e-05 - val_accuracy: 1.0000
# Epoch 906/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 1.7174e-04 - accuracy: 1.0000 - val_loss: 4.1798e-05 - val_accuracy: 1.0000
# Epoch 907/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 5.5545e-04 - accuracy: 1.0000 - val_loss: 4.7558e-05 - val_accuracy: 1.0000
# Epoch 908/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.6164e-04 - accuracy: 1.0000 - val_loss: 4.9127e-05 - val_accuracy: 1.0000
# Epoch 909/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 1.3221e-04 - accuracy: 1.0000 - val_loss: 4.4322e-05 - val_accuracy: 1.0000
# Epoch 910/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 2.5209e-04 - accuracy: 1.0000 - val_loss: 4.2888e-05 - val_accuracy: 1.0000
# Epoch 911/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 1.4508e-04 - accuracy: 1.0000 - val_loss: 4.5202e-05 - val_accuracy: 1.0000
# Epoch 912/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 1.8152e-04 - accuracy: 1.0000 - val_loss: 4.2042e-05 - val_accuracy: 1.0000
# Epoch 913/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 2.9309e-04 - accuracy: 1.0000 - val_loss: 4.0457e-05 - val_accuracy: 1.0000
# Epoch 914/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 2.5697e-04 - accuracy: 1.0000 - val_loss: 4.0303e-05 - val_accuracy: 1.0000
# Epoch 915/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 3.2920e-04 - accuracy: 1.0000 - val_loss: 3.9025e-05 - val_accuracy: 1.0000
# Epoch 916/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.4897e-04 - accuracy: 1.0000 - val_loss: 3.8465e-05 - val_accuracy: 1.0000
# Epoch 917/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 3.8498e-04 - accuracy: 1.0000 - val_loss: 4.7902e-05 - val_accuracy: 1.0000
# Epoch 918/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 2.1601e-04 - accuracy: 1.0000 - val_loss: 4.2101e-05 - val_accuracy: 1.0000
# Epoch 919/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 1.9638e-04 - accuracy: 1.0000 - val_loss: 3.8416e-05 - val_accuracy: 1.0000
# Epoch 920/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 2.3793e-04 - accuracy: 1.0000 - val_loss: 3.8569e-05 - val_accuracy: 1.0000
# Epoch 921/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 2.1050e-04 - accuracy: 1.0000 - val_loss: 3.8368e-05 - val_accuracy: 1.0000
# Epoch 922/1000
# 18/18 [==============================] - 0s 14ms/step - loss: 1.1758e-04 - accuracy: 1.0000 - val_loss: 3.7725e-05 - val_accuracy: 1.0000
# Epoch 923/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 2.3638e-04 - accuracy: 1.0000 - val_loss: 3.8129e-05 - val_accuracy: 1.0000
# Epoch 924/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 2.4830e-04 - accuracy: 1.0000 - val_loss: 3.8684e-05 - val_accuracy: 1.0000
# Epoch 925/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 1.8822e-04 - accuracy: 1.0000 - val_loss: 3.7028e-05 - val_accuracy: 1.0000
# Epoch 926/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 2.6679e-04 - accuracy: 1.0000 - val_loss: 3.8674e-05 - val_accuracy: 1.0000
# Epoch 927/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 8.0687e-04 - accuracy: 1.0000 - val_loss: 5.2978e-05 - val_accuracy: 1.0000
# Epoch 928/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 2.7161e-04 - accuracy: 1.0000 - val_loss: 4.5600e-05 - val_accuracy: 1.0000
# Epoch 929/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.5152e-04 - accuracy: 1.0000 - val_loss: 3.9046e-05 - val_accuracy: 1.0000
# Epoch 930/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 2.4541e-04 - accuracy: 1.0000 - val_loss: 3.6750e-05 - val_accuracy: 1.0000
# Epoch 931/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 1.4464e-04 - accuracy: 1.0000 - val_loss: 3.8093e-05 - val_accuracy: 1.0000
# Epoch 932/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.9714e-04 - accuracy: 1.0000 - val_loss: 3.6940e-05 - val_accuracy: 1.0000
# Epoch 933/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.4380e-04 - accuracy: 1.0000 - val_loss: 3.5989e-05 - val_accuracy: 1.0000
# Epoch 934/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.8548e-04 - accuracy: 1.0000 - val_loss: 3.5587e-05 - val_accuracy: 1.0000
# Epoch 935/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 2.9685e-04 - accuracy: 1.0000 - val_loss: 3.3983e-05 - val_accuracy: 1.0000
# Epoch 936/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.9099e-04 - accuracy: 1.0000 - val_loss: 3.7851e-05 - val_accuracy: 1.0000
# Epoch 937/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 4.4194e-04 - accuracy: 1.0000 - val_loss: 5.3570e-05 - val_accuracy: 1.0000
# Epoch 938/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 3.0191e-04 - accuracy: 1.0000 - val_loss: 4.0187e-05 - val_accuracy: 1.0000
# Epoch 939/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 2.8140e-04 - accuracy: 1.0000 - val_loss: 3.6454e-05 - val_accuracy: 1.0000
# Epoch 940/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 2.1425e-04 - accuracy: 1.0000 - val_loss: 3.7514e-05 - val_accuracy: 1.0000
# Epoch 941/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 1.2037e-04 - accuracy: 1.0000 - val_loss: 3.5816e-05 - val_accuracy: 1.0000
# Epoch 942/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 1.8134e-04 - accuracy: 1.0000 - val_loss: 3.3937e-05 - val_accuracy: 1.0000
# Epoch 943/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 1.5284e-04 - accuracy: 1.0000 - val_loss: 3.3498e-05 - val_accuracy: 1.0000
# Epoch 944/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.6858e-04 - accuracy: 1.0000 - val_loss: 3.1518e-05 - val_accuracy: 1.0000
# Epoch 945/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 3.9630e-04 - accuracy: 1.0000 - val_loss: 3.5769e-05 - val_accuracy: 1.0000
# Epoch 946/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.8767e-04 - accuracy: 1.0000 - val_loss: 3.2962e-05 - val_accuracy: 1.0000
# Epoch 947/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 3.2253e-04 - accuracy: 1.0000 - val_loss: 3.1738e-05 - val_accuracy: 1.0000
# Epoch 948/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.4329e-04 - accuracy: 1.0000 - val_loss: 3.1267e-05 - val_accuracy: 1.0000
# Epoch 949/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 1.0880e-04 - accuracy: 1.0000 - val_loss: 3.2083e-05 - val_accuracy: 1.0000
# Epoch 950/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.2044e-04 - accuracy: 1.0000 - val_loss: 3.1148e-05 - val_accuracy: 1.0000
# Epoch 951/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 1.4530e-04 - accuracy: 1.0000 - val_loss: 3.1074e-05 - val_accuracy: 1.0000
# Epoch 952/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 2.0011e-04 - accuracy: 1.0000 - val_loss: 3.1758e-05 - val_accuracy: 1.0000
# Epoch 953/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.9631e-04 - accuracy: 1.0000 - val_loss: 3.1853e-05 - val_accuracy: 1.0000
# Epoch 954/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 2.4853e-04 - accuracy: 1.0000 - val_loss: 3.5355e-05 - val_accuracy: 1.0000
# Epoch 955/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.8830e-04 - accuracy: 1.0000 - val_loss: 3.2718e-05 - val_accuracy: 1.0000
# Epoch 956/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.7870e-04 - accuracy: 1.0000 - val_loss: 3.1127e-05 - val_accuracy: 1.0000
# Epoch 957/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 8.8956e-05 - accuracy: 1.0000 - val_loss: 3.1053e-05 - val_accuracy: 1.0000
# Epoch 958/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 9.4636e-05 - accuracy: 1.0000 - val_loss: 3.0643e-05 - val_accuracy: 1.0000
# Epoch 959/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.9410e-04 - accuracy: 1.0000 - val_loss: 3.1663e-05 - val_accuracy: 1.0000
# Epoch 960/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 2.5636e-04 - accuracy: 1.0000 - val_loss: 2.9977e-05 - val_accuracy: 1.0000
# Epoch 961/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 9.1766e-05 - accuracy: 1.0000 - val_loss: 2.9759e-05 - val_accuracy: 1.0000
# Epoch 962/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 1.7163e-04 - accuracy: 1.0000 - val_loss: 2.8882e-05 - val_accuracy: 1.0000
# Epoch 963/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 1.1012e-04 - accuracy: 1.0000 - val_loss: 2.8382e-05 - val_accuracy: 1.0000
# Epoch 964/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.3991e-04 - accuracy: 1.0000 - val_loss: 2.7513e-05 - val_accuracy: 1.0000
# Epoch 965/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.4224e-04 - accuracy: 1.0000 - val_loss: 2.7482e-05 - val_accuracy: 1.0000
# Epoch 966/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 2.2247e-04 - accuracy: 1.0000 - val_loss: 2.7206e-05 - val_accuracy: 1.0000
# Epoch 967/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 1.4325e-04 - accuracy: 1.0000 - val_loss: 2.7141e-05 - val_accuracy: 1.0000
# Epoch 968/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 1.8176e-04 - accuracy: 1.0000 - val_loss: 2.7091e-05 - val_accuracy: 1.0000
# Epoch 969/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.7013e-04 - accuracy: 1.0000 - val_loss: 2.6947e-05 - val_accuracy: 1.0000
# Epoch 970/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 2.0954e-04 - accuracy: 1.0000 - val_loss: 2.7230e-05 - val_accuracy: 1.0000
# Epoch 971/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 1.5387e-04 - accuracy: 1.0000 - val_loss: 2.6267e-05 - val_accuracy: 1.0000
# Epoch 972/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 1.7098e-04 - accuracy: 1.0000 - val_loss: 2.5537e-05 - val_accuracy: 1.0000
# Epoch 973/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.1407e-04 - accuracy: 1.0000 - val_loss: 2.5545e-05 - val_accuracy: 1.0000
# Epoch 974/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.8602e-04 - accuracy: 1.0000 - val_loss: 2.6278e-05 - val_accuracy: 1.0000
# Epoch 975/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.2192e-04 - accuracy: 1.0000 - val_loss: 2.6416e-05 - val_accuracy: 1.0000
# Epoch 976/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.1921e-04 - accuracy: 1.0000 - val_loss: 2.5919e-05 - val_accuracy: 1.0000
# Epoch 977/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 1.3302e-04 - accuracy: 1.0000 - val_loss: 2.5435e-05 - val_accuracy: 1.0000
# Epoch 978/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.1195e-04 - accuracy: 1.0000 - val_loss: 2.5398e-05 - val_accuracy: 1.0000
# Epoch 979/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 9.8595e-05 - accuracy: 1.0000 - val_loss: 2.5633e-05 - val_accuracy: 1.0000
# Epoch 980/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 6.4097e-04 - accuracy: 1.0000 - val_loss: 3.0831e-05 - val_accuracy: 1.0000
# Epoch 981/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 1.8174e-04 - accuracy: 1.0000 - val_loss: 4.1590e-05 - val_accuracy: 1.0000
# Epoch 982/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 2.1157e-04 - accuracy: 1.0000 - val_loss: 2.8748e-05 - val_accuracy: 1.0000
# Epoch 983/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.9170e-04 - accuracy: 1.0000 - val_loss: 2.5884e-05 - val_accuracy: 1.0000
# Epoch 984/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.2162e-04 - accuracy: 1.0000 - val_loss: 2.5391e-05 - val_accuracy: 1.0000
# Epoch 985/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 8.5615e-05 - accuracy: 1.0000 - val_loss: 2.4533e-05 - val_accuracy: 1.0000
# Epoch 986/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.0136e-04 - accuracy: 1.0000 - val_loss: 2.4159e-05 - val_accuracy: 1.0000
# Epoch 987/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.2933e-04 - accuracy: 1.0000 - val_loss: 2.4979e-05 - val_accuracy: 1.0000
# Epoch 988/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.2939e-04 - accuracy: 1.0000 - val_loss: 2.4629e-05 - val_accuracy: 1.0000
# Epoch 989/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 8.9980e-05 - accuracy: 1.0000 - val_loss: 2.5072e-05 - val_accuracy: 1.0000
# Epoch 990/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.0348e-04 - accuracy: 1.0000 - val_loss: 2.4638e-05 - val_accuracy: 1.0000
# Epoch 991/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 1.0343e-04 - accuracy: 1.0000 - val_loss: 2.4068e-05 - val_accuracy: 1.0000
# Epoch 992/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 4.1498e-04 - accuracy: 1.0000 - val_loss: 2.3928e-05 - val_accuracy: 1.0000
# Epoch 993/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.7113e-04 - accuracy: 1.0000 - val_loss: 2.5745e-05 - val_accuracy: 1.0000
# Epoch 994/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 9.6139e-04 - accuracy: 1.0000 - val_loss: 4.6429e-05 - val_accuracy: 1.0000
# Epoch 995/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 3.9593e-04 - accuracy: 1.0000 - val_loss: 4.5674e-05 - val_accuracy: 1.0000
# Epoch 996/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 3.2389e-04 - accuracy: 1.0000 - val_loss: 3.0046e-05 - val_accuracy: 1.0000
# Epoch 997/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 1.0296e-04 - accuracy: 1.0000 - val_loss: 2.8263e-05 - val_accuracy: 1.0000
# Epoch 998/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 4.5076e-04 - accuracy: 1.0000 - val_loss: 3.0567e-05 - val_accuracy: 1.0000
# Epoch 999/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 2.3977e-04 - accuracy: 1.0000 - val_loss: 3.6519e-05 - val_accuracy: 1.0000
# Epoch 1000/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 1.7674e-04 - accuracy: 1.0000 - val_loss: 2.8140e-05 - val_accuracy: 1.0000

# %%
#-----------------------------------------------------------------------------------------------------------
#Plot the architecture (with netron)
#-----------------------------------------------------------------------------------------------------------
from tensorflow.keras.utils import plot_model
import pydot
#for this to work pip install pydot
#install graphviz.exe for windows: https://graphviz.gitlab.io/download/

#Save the model:
#model.save('./figures%s/Planck_NN_model.h5' %PS)

import netron
#netron.start('./figures%s/Planck_NN_model.h5' %PS)

# %% [markdown]
# ### Learning curves visualization

# %%
#-----------------------------------------------------------------------------------------------------------
#Accuracy plot
#-----------------------------------------------------------------------------------------------------------
fig = plt.figure(figsize=(8,6))
plt.plot(History.history['accuracy'])
plt.plot(History.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='lower right')
plt.grid(color='lightgray', linestyle='--')
plt.show()

# %%
#-----------------------------------------------------------------------------------------------------------
#Loss plot
#-----------------------------------------------------------------------------------------------------------
fig = plt.figure(figsize=(8,6))
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.grid(color='lightgray', linestyle='--')
plt.show()

# %% [markdown]
# ### Testing the NNs

# %%
#Function for the probability of classification as LCDM 
def normFeat(p):
  if 0<p<0.5:
    rr=1-p
  else:
    rr=p
  return rr

#Function for the probability of classification as Feature 
def normLCDM(p):
  if 0<p<0.5:
    rr=p
  else:
    rr=1-p
  return rr

# %%
#-----------------------------------------------------------------------------------------------------------
#Test the NN
#-----------------------------------------------------------------------------------------------------------
theory = ['LCDM','FT']

true_model=[]
pred_model=[]
prob_pred_MoG=[]
prob_pred_LCDM=[]
for i in range(len(X_test)):
  X_test_tf = tf.convert_to_tensor([X_test[i]])
  predictions = model.predict(X_test_tf)
  true_model.append(round(y_test[i]))
  pred_model.append(round(predictions[0][0]))
  prob_pred_MoG.append(round(100*normFeat(predictions[0][0]),3))
  prob_pred_LCDM.append(round(100*normLCDM(predictions[0][0]),3))
# Out:
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 32ms/step

# %% [markdown]
# ### Performance verification of the NNs

# %%
#-----------------------------------------------------------------------------------------------------------
#Performance: correct & incorrect  predictions
#-----------------------------------------------------------------------------------------------------------
true_LCDM = []
true_MoG = []
false_LCDM = []
false_MoG = []

for pred, true in zip(pred_model, true_model):
    if pred==0 and true==0:
        true_LCDM.append(1)
    if pred==1 and true==1:
        true_MoG.append(1)
    if pred==0 and true==1:
        false_LCDM.append(1)
    if pred==1 and true==0:
        false_MoG.append(1)
lenghts=[len(true_LCDM),len(true_MoG),len(false_LCDM),len(false_MoG)]

print('     ','LCDM','MoG')
print('True ',len(true_LCDM)/sum(lenghts),len(true_MoG)/sum(lenghts))
print('False',len(false_LCDM)/sum(lenghts),len(false_MoG)/sum(lenghts))
print('--------------')
print("Correct prediction: ",(len(true_LCDM)+len(true_MoG))/sum(lenghts))
print("Wrong prediction  : ",(len(false_LCDM)+len(false_MoG))/sum(lenghts))
# Out:
#       LCDM MoG
# True  0.5 0.5
# False 0.0 0.0
# --------------
# Correct prediction:  1.0
# Wrong prediction  :  0.0

# %%
#-----------------------------------------------------------------------------------------------------------
#Probability distribution of classification as Feature
#-----------------------------------------------------------------------------------------------------------
fig = plt.figure(figsize=(8,6))
plt.hist(prob_pred_MoG, label='Feature', alpha=0.6, color='#FF7F0E')
plt.xlabel('Predicted probability')
plt.ylabel('Number of samples')
plt.legend()
plt.show()

# %%
#-----------------------------------------------------------------------------------------------------------
#Probability distribution of classification as LCDM
#-----------------------------------------------------------------------------------------------------------
fig = plt.figure(figsize=(8,6))
plt.hist(prob_pred_LCDM, label='$\Lambda$CDM', alpha=0.6)
plt.xlabel('Predicted probability')
plt.ylabel('Number of samples')
plt.legend()
plt.show()

# %%
#-----------------------------------------------------------------------------------------------------------
##Confusion matrix
#-----------------------------------------------------------------------------------------------------------
from sklearn import metrics
import seaborn as sns
fsize=18
cm = metrics.confusion_matrix(true_model, pred_model)

#Create normalized Confusion Matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

heatmap = sns.heatmap(cm_normalized, 
            annot=True, 
            annot_kws={"size": fsize},
            linewidths=0.01,
            fmt=".2f", 
            xticklabels=['$\Lambda$CDM', 'Feature'],
            yticklabels=['$\Lambda$CDM', 'Feature'], cmap='RdPu')
plt.xlabel('Predicted Class', fontsize=fsize, labelpad=15)
plt.ylabel('True Class', fontsize=fsize, labelpad=15)

plt.xticks(fontsize=fsize)
plt.yticks(fontsize=fsize)

num_ticks = 2  
x_ticks = np.array([0, 1])
colorbar = heatmap.collections[0].colorbar
colorbar.ax.set_yticks(np.linspace(0, 1, num_ticks))
colorbar.ax.set_yticklabels(x_ticks, fontsize=fsize)

plt.title('$\;$\n\n$C_{\ell}^{EE}$', fontsize=20)
plt.tight_layout()
plt.savefig('./figures_feature/conf_matrix_EE_feature.pdf')
plt.show()

# %%
#Read real Planck data
Full_planck_TE = np.genfromtxt('./experimental_data/COM_PowerSpect_CMB-TE-binned_R3.02.txt', 
                          delimiter=None, skip_header=1, comments='#')
planck_TE = [Full_planck_TE[i,4] for i in range(len(Full_planck_TE))]

# %%
#Test NN on real Planck data (best fit)
Planck_label = model.predict(tf.convert_to_tensor([planck_TE]))
# Out:
# 1/1 [==============================] - 0s 129ms/step

# %%
print("The data belongs to the class:",Planck_label[0][0])
# Out:
# The data belongs to the class: 0.0
