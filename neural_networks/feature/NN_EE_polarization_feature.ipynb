# %% [markdown]
# # **Neural Networks for model selection, $\mathcal{C}^{EE}_{\ell}$ data**
# ## Primordial Feature template vs ΛCDM
# Can the NN differentiate a primoridal feature template and the ΛCDM models at the level of the CMB angular power spectrum?

# %%
#Import packages
import pandas as pd
import numpy as np
import math
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.layers.experimental.preprocessing import Normalization
from matplotlib import pyplot as plt
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ### Read and visualize the data (simulated out of [CLASS](https://github.com/lesgourg/class_public) and the [ESA Planck Archival](https://pla.esac.esa.int/#home))

# %%
#Read the data
PS = '_EEcls'
label_Ax0 = 'Ax_e-2'
planck_df_LCDM = np.genfromtxt('./simulated_data/EE_polarization/clsEE_LCDM_noisy.csv', delimiter=',')
planck_df_MoG = np.genfromtxt('./simulated_data/EE_polarization/clsEE_Feature_noisy%s.csv'%label_Ax0, delimiter=',')
planck_cls_LCDM = planck_df_LCDM[1:] # get rid of the first column, i.e. multipole moment l
planck_cls_MoG = planck_df_MoG[1:]
ls = planck_df_LCDM[0]

#Add the model class: 
LCDM_class = np.zeros(len(planck_cls_LCDM))
MoG_class = np.ones(len(planck_cls_MoG))

#Full arrays (+target):
cls_LCDM_class = np.column_stack((planck_cls_LCDM, LCDM_class))
cls_MoG_class = np.column_stack((planck_cls_MoG, MoG_class))

#Full data set (LCDM + MoG)
cls_full_dataset = np.concatenate((planck_cls_LCDM, planck_cls_MoG)) #without the class: x_dataset
dataset_class = np.concatenate((LCDM_class, MoG_class)) #only the class: y_dataset
cls_full_dataset_class = np.concatenate((cls_LCDM_class, cls_MoG_class)) #with the class: xy_dataset

# %%
#Plot the differences LCDM - MoG
plt.plot(ls,planck_cls_LCDM[0]-planck_cls_MoG[0])
plt.xlabel('Multipole moment ${\ell}$')
plt.ylabel('$\mathcal{C}^{EE}_{\ell}(\Lambda CDM)$ - $\mathcal{C}^{EE}_{\ell} (Feature)$')
# Out:
# Text(0, 0.5, '$\\mathcal{C}^{EE}_{\\ell}(\\Lambda CDM)$ - $\\mathcal{C}^{EE}_{\\ell} (Feature)$')

# %% [markdown]
# ## Angular power spectrum (EE component)

# %%
#-----------------------------------------------------------------------------------------------------------------------
#Plot Cls
#-----------------------------------------------------------------------------------------------------------------------
fig = plt.figure(figsize=(8,6))
plt.scatter(ls,cls_full_dataset[50:][0], label='$\Lambda$CDM', marker='o', s=8)
plt.scatter(ls,cls_full_dataset[50:][249], label='Feature', marker='o', s=8)
plt.xlabel('${\ell}$')
plt.ylabel('$\mathcal{C}^{EE}_{\ell}$')
plt.legend()
plt.grid(color='lightgray', linestyle='--')

# %%
#-----------------------------------------------------------------------------------------------------------------------
#Plot Dls
#-----------------------------------------------------------------------------------------------------------------------
# Create a function for converting the C_ls^EE to Dls Tcmb=2.7255
def Dls(l,CEE):
    Dl = [l[i]*(l[i]+1)*CEE[i]/((2*math.pi)*(2.7255*10**6)**2) for i in range(len(l))]
    return Dl
#-----------------------------------------------------------------------------------------------------------------------
fig = plt.figure(figsize=(8,6))
plt.plot(ls,Dls(ls,cls_full_dataset[:50][0]), label='$\Lambda$CDM')
plt.plot(ls,Dls(ls,cls_full_dataset[50:][249]), label='Feature')
plt.xlabel('${\ell}$')
plt.ylabel('$\mathcal{D}^{EE}_{\ell}$')
plt.legend()
plt.grid(color='lightgray', linestyle='--')

# %% [markdown]
# ### Z-score normalization of the $\mathcal{C}^{EE}_{\ell}$ data

# %%
#-------------------------------------------------------------------------------------------------------------
#Normalization and visualization
#-------------------------------------------------------------------------------------------------------------
fig = plt.figure(figsize=(8,6))
normalize = Normalization()
normalize.adapt(cls_full_dataset)
normalized_data = normalize(cls_full_dataset)
plt.scatter(ls,normalized_data[0], label='$\Lambda$CDM', marker='o', s=8)
plt.scatter(ls,normalized_data[-1], label='Feature', marker='o', s=8)
plt.grid(color='lightgray', linestyle='--')
plt.legend()
plt.xlabel('${\ell}$')
plt.ylabel('Normalized $\mathcal{C}^{EE}_{\ell}$')
# Out:
# Text(0, 0.5, 'Normalized $\\mathcal{C}^{EE}_{\\ell}$')

# %%
#Z-SCORE verification
print('var: %.4f' % np.var(normalized_data))
print('mean: %.4f' % np.mean(normalized_data))
# Out:
# var: 1.0000
# mean: 0.0000

# %% [markdown]
# ### Training the neural networks

# %%
#Train_test_split
from sklearn.model_selection import train_test_split
normalized_data_numpy = normalized_data.numpy()
X_train, X_test, y_train, y_test = train_test_split(normalized_data_numpy, dataset_class, test_size=0.3, random_state=42)
#Training and validation split with fixed random seed
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
#Redefine the model's architecture to display the input layer: (functional API)
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout

inputs = Input(shape=(len(normalized_data[0]),), name='input_layer') #shape=X_train.shape[1],
hidden_layer = Dense(32, activation='relu', name='hidden_layer')(inputs)
dropout_layer = Dropout(rate=0.2, name='dropout_layer')(hidden_layer)
outputs = Dense(1, activation='sigmoid', name='output_layer')(dropout_layer)

#Create the model
model = Model(inputs=inputs, outputs=outputs, name='Angular_PS_NN')

#Model details
model.summary()
# Out:
# Model: "Angular_PS_NN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 66)]              0
#
#  hidden_layer (Dense)        (None, 32)                2144
#
#  dropout_layer (Dropout)     (None, 32)                0
#
#  output_layer (Dense)        (None, 1)                 33
#
# =================================================================
# Total params: 2177 (8.50 KB)
# Trainable params: 2177 (8.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#-----------------------------------------------------------------------------------------------------------
#Training the NN
#-----------------------------------------------------------------------------------------------------------
model.reset_states()
#Compile model:
model.compile(optimizer=Adam(learning_rate=0.0002), loss='binary_crossentropy', metrics=['accuracy'])

#Training:
History = model.fit(X_train, y_train, epochs=1000, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Epoch 1/1000
# 18/18 [==============================] - 1s 12ms/step - loss: 0.8483 - accuracy: 0.5393 - val_loss: 0.8296 - val_accuracy: 0.5071
# Epoch 2/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.7668 - accuracy: 0.5375 - val_loss: 0.7505 - val_accuracy: 0.5000
# Epoch 3/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.7121 - accuracy: 0.5839 - val_loss: 0.6897 - val_accuracy: 0.5286
# Epoch 4/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6761 - accuracy: 0.5679 - val_loss: 0.6538 - val_accuracy: 0.6000
# Epoch 5/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6419 - accuracy: 0.6321 - val_loss: 0.6301 - val_accuracy: 0.6500
# Epoch 6/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6282 - accuracy: 0.6661 - val_loss: 0.6095 - val_accuracy: 0.8714
# Epoch 7/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6246 - accuracy: 0.6964 - val_loss: 0.5923 - val_accuracy: 0.9643
# Epoch 8/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5902 - accuracy: 0.7446 - val_loss: 0.5773 - val_accuracy: 0.9500
# Epoch 9/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5789 - accuracy: 0.7554 - val_loss: 0.5646 - val_accuracy: 0.9286
# Epoch 10/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5797 - accuracy: 0.7536 - val_loss: 0.5507 - val_accuracy: 0.9286
# Epoch 11/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5594 - accuracy: 0.7875 - val_loss: 0.5368 - val_accuracy: 0.9214
# Epoch 12/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5499 - accuracy: 0.7929 - val_loss: 0.5237 - val_accuracy: 0.9071
# Epoch 13/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5462 - accuracy: 0.8000 - val_loss: 0.5112 - val_accuracy: 0.9286
# Epoch 14/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5178 - accuracy: 0.8196 - val_loss: 0.4985 - val_accuracy: 0.9214
# Epoch 15/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5124 - accuracy: 0.8268 - val_loss: 0.4874 - val_accuracy: 0.9214
# Epoch 16/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5148 - accuracy: 0.8232 - val_loss: 0.4752 - val_accuracy: 0.9143
# Epoch 17/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4878 - accuracy: 0.8518 - val_loss: 0.4655 - val_accuracy: 0.9214
# Epoch 18/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4892 - accuracy: 0.8393 - val_loss: 0.4559 - val_accuracy: 0.9071
# Epoch 19/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4667 - accuracy: 0.8679 - val_loss: 0.4446 - val_accuracy: 0.9143
# Epoch 20/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4542 - accuracy: 0.8714 - val_loss: 0.4338 - val_accuracy: 0.9214
# Epoch 21/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4506 - accuracy: 0.8821 - val_loss: 0.4238 - val_accuracy: 0.9214
# Epoch 22/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4423 - accuracy: 0.8750 - val_loss: 0.4139 - val_accuracy: 0.9214
# Epoch 23/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4367 - accuracy: 0.8821 - val_loss: 0.4045 - val_accuracy: 0.9214
# Epoch 24/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4182 - accuracy: 0.8786 - val_loss: 0.3956 - val_accuracy: 0.9214
# Epoch 25/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4231 - accuracy: 0.8750 - val_loss: 0.3866 - val_accuracy: 0.9214
# Epoch 26/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4053 - accuracy: 0.8911 - val_loss: 0.3776 - val_accuracy: 0.9214
# Epoch 27/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3988 - accuracy: 0.8911 - val_loss: 0.3681 - val_accuracy: 0.9214
# Epoch 28/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3897 - accuracy: 0.8964 - val_loss: 0.3598 - val_accuracy: 0.9214
# Epoch 29/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3920 - accuracy: 0.8821 - val_loss: 0.3529 - val_accuracy: 0.9214
# Epoch 30/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3744 - accuracy: 0.9000 - val_loss: 0.3446 - val_accuracy: 0.9214
# Epoch 31/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3753 - accuracy: 0.8946 - val_loss: 0.3365 - val_accuracy: 0.9214
# Epoch 32/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3595 - accuracy: 0.9054 - val_loss: 0.3293 - val_accuracy: 0.9214
# Epoch 33/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3467 - accuracy: 0.9054 - val_loss: 0.3217 - val_accuracy: 0.9214
# Epoch 34/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3495 - accuracy: 0.9018 - val_loss: 0.3144 - val_accuracy: 0.9214
# Epoch 35/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3303 - accuracy: 0.9036 - val_loss: 0.3075 - val_accuracy: 0.9214
# Epoch 36/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3252 - accuracy: 0.9214 - val_loss: 0.3015 - val_accuracy: 0.9214
# Epoch 37/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3200 - accuracy: 0.9125 - val_loss: 0.2943 - val_accuracy: 0.9214
# Epoch 38/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3193 - accuracy: 0.9250 - val_loss: 0.2886 - val_accuracy: 0.9214
# Epoch 39/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3128 - accuracy: 0.9071 - val_loss: 0.2818 - val_accuracy: 0.9214
# Epoch 40/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3094 - accuracy: 0.9143 - val_loss: 0.2768 - val_accuracy: 0.9214
# Epoch 41/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3008 - accuracy: 0.9179 - val_loss: 0.2713 - val_accuracy: 0.9357
# Epoch 42/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2947 - accuracy: 0.9232 - val_loss: 0.2652 - val_accuracy: 0.9214
# Epoch 43/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2893 - accuracy: 0.9321 - val_loss: 0.2593 - val_accuracy: 0.9214
# Epoch 44/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2872 - accuracy: 0.9125 - val_loss: 0.2541 - val_accuracy: 0.9286
# Epoch 45/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2787 - accuracy: 0.9250 - val_loss: 0.2493 - val_accuracy: 0.9286
# Epoch 46/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2843 - accuracy: 0.9179 - val_loss: 0.2465 - val_accuracy: 0.9357
# Epoch 47/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2724 - accuracy: 0.9214 - val_loss: 0.2402 - val_accuracy: 0.9357
# Epoch 48/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2670 - accuracy: 0.9250 - val_loss: 0.2357 - val_accuracy: 0.9357
# Epoch 49/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2653 - accuracy: 0.9357 - val_loss: 0.2306 - val_accuracy: 0.9357
# Epoch 50/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2607 - accuracy: 0.9232 - val_loss: 0.2272 - val_accuracy: 0.9429
# Epoch 51/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2639 - accuracy: 0.9232 - val_loss: 0.2232 - val_accuracy: 0.9429
# Epoch 52/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2509 - accuracy: 0.9250 - val_loss: 0.2186 - val_accuracy: 0.9500
# Epoch 53/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2457 - accuracy: 0.9339 - val_loss: 0.2149 - val_accuracy: 0.9429
# Epoch 54/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2381 - accuracy: 0.9321 - val_loss: 0.2113 - val_accuracy: 0.9500
# Epoch 55/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2366 - accuracy: 0.9375 - val_loss: 0.2071 - val_accuracy: 0.9500
# Epoch 56/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2305 - accuracy: 0.9446 - val_loss: 0.2029 - val_accuracy: 0.9500
# Epoch 57/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2263 - accuracy: 0.9464 - val_loss: 0.1996 - val_accuracy: 0.9500
# Epoch 58/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2210 - accuracy: 0.9482 - val_loss: 0.1960 - val_accuracy: 0.9429
# Epoch 59/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.2189 - accuracy: 0.9393 - val_loss: 0.1926 - val_accuracy: 0.9500
# Epoch 60/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2156 - accuracy: 0.9500 - val_loss: 0.1883 - val_accuracy: 0.9500
# Epoch 61/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2202 - accuracy: 0.9357 - val_loss: 0.1846 - val_accuracy: 0.9429
# Epoch 62/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2035 - accuracy: 0.9518 - val_loss: 0.1810 - val_accuracy: 0.9429
# Epoch 63/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2047 - accuracy: 0.9464 - val_loss: 0.1782 - val_accuracy: 0.9429
# Epoch 64/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2015 - accuracy: 0.9482 - val_loss: 0.1747 - val_accuracy: 0.9429
# Epoch 65/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1935 - accuracy: 0.9571 - val_loss: 0.1705 - val_accuracy: 0.9429
# Epoch 66/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1950 - accuracy: 0.9518 - val_loss: 0.1668 - val_accuracy: 0.9429
# Epoch 67/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1898 - accuracy: 0.9500 - val_loss: 0.1629 - val_accuracy: 0.9500
# Epoch 68/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1839 - accuracy: 0.9446 - val_loss: 0.1601 - val_accuracy: 0.9500
# Epoch 69/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1808 - accuracy: 0.9554 - val_loss: 0.1573 - val_accuracy: 0.9571
# Epoch 70/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1826 - accuracy: 0.9536 - val_loss: 0.1541 - val_accuracy: 0.9500
# Epoch 71/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1843 - accuracy: 0.9464 - val_loss: 0.1514 - val_accuracy: 0.9571
# Epoch 72/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1702 - accuracy: 0.9625 - val_loss: 0.1486 - val_accuracy: 0.9643
# Epoch 73/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1702 - accuracy: 0.9589 - val_loss: 0.1461 - val_accuracy: 0.9714
# Epoch 74/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1683 - accuracy: 0.9589 - val_loss: 0.1433 - val_accuracy: 0.9643
# Epoch 75/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1651 - accuracy: 0.9625 - val_loss: 0.1407 - val_accuracy: 0.9643
# Epoch 76/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1676 - accuracy: 0.9643 - val_loss: 0.1384 - val_accuracy: 0.9786
# Epoch 77/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1583 - accuracy: 0.9607 - val_loss: 0.1355 - val_accuracy: 0.9857
# Epoch 78/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1539 - accuracy: 0.9661 - val_loss: 0.1329 - val_accuracy: 0.9714
# Epoch 79/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.1552 - accuracy: 0.9679 - val_loss: 0.1299 - val_accuracy: 0.9857
# Epoch 80/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1535 - accuracy: 0.9804 - val_loss: 0.1265 - val_accuracy: 1.0000
# Epoch 81/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1482 - accuracy: 0.9696 - val_loss: 0.1244 - val_accuracy: 0.9857
# Epoch 82/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1405 - accuracy: 0.9786 - val_loss: 0.1223 - val_accuracy: 0.9857
# Epoch 83/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1407 - accuracy: 0.9821 - val_loss: 0.1196 - val_accuracy: 0.9929
# Epoch 84/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1398 - accuracy: 0.9643 - val_loss: 0.1184 - val_accuracy: 0.9857
# Epoch 85/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1327 - accuracy: 0.9804 - val_loss: 0.1167 - val_accuracy: 0.9857
# Epoch 86/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.1407 - accuracy: 0.9661 - val_loss: 0.1143 - val_accuracy: 1.0000
# Epoch 87/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1340 - accuracy: 0.9786 - val_loss: 0.1122 - val_accuracy: 1.0000
# Epoch 88/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1265 - accuracy: 0.9768 - val_loss: 0.1107 - val_accuracy: 1.0000
# Epoch 89/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1273 - accuracy: 0.9786 - val_loss: 0.1092 - val_accuracy: 0.9929
# Epoch 90/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1337 - accuracy: 0.9768 - val_loss: 0.1078 - val_accuracy: 0.9857
# Epoch 91/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1315 - accuracy: 0.9768 - val_loss: 0.1057 - val_accuracy: 0.9857
# Epoch 92/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1241 - accuracy: 0.9804 - val_loss: 0.1038 - val_accuracy: 1.0000
# Epoch 93/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1227 - accuracy: 0.9821 - val_loss: 0.1026 - val_accuracy: 0.9857
# Epoch 94/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1245 - accuracy: 0.9768 - val_loss: 0.1009 - val_accuracy: 0.9857
# Epoch 95/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1206 - accuracy: 0.9768 - val_loss: 0.0990 - val_accuracy: 1.0000
# Epoch 96/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1171 - accuracy: 0.9857 - val_loss: 0.0973 - val_accuracy: 1.0000
# Epoch 97/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1216 - accuracy: 0.9786 - val_loss: 0.0961 - val_accuracy: 1.0000
# Epoch 98/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1104 - accuracy: 0.9857 - val_loss: 0.0953 - val_accuracy: 0.9857
# Epoch 99/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1134 - accuracy: 0.9768 - val_loss: 0.0937 - val_accuracy: 1.0000
# Epoch 100/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1166 - accuracy: 0.9750 - val_loss: 0.0924 - val_accuracy: 1.0000
# Epoch 101/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1094 - accuracy: 0.9857 - val_loss: 0.0910 - val_accuracy: 1.0000
# Epoch 102/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1088 - accuracy: 0.9857 - val_loss: 0.0896 - val_accuracy: 1.0000
# Epoch 103/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1105 - accuracy: 0.9857 - val_loss: 0.0886 - val_accuracy: 1.0000
# Epoch 104/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1055 - accuracy: 0.9804 - val_loss: 0.0873 - val_accuracy: 1.0000
# Epoch 105/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1059 - accuracy: 0.9821 - val_loss: 0.0858 - val_accuracy: 1.0000
# Epoch 106/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1026 - accuracy: 0.9875 - val_loss: 0.0850 - val_accuracy: 1.0000
# Epoch 107/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1071 - accuracy: 0.9804 - val_loss: 0.0835 - val_accuracy: 1.0000
# Epoch 108/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1012 - accuracy: 0.9821 - val_loss: 0.0827 - val_accuracy: 1.0000
# Epoch 109/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0918 - accuracy: 0.9893 - val_loss: 0.0812 - val_accuracy: 1.0000
# Epoch 110/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0957 - accuracy: 0.9911 - val_loss: 0.0806 - val_accuracy: 1.0000
# Epoch 111/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0934 - accuracy: 0.9911 - val_loss: 0.0786 - val_accuracy: 1.0000
# Epoch 112/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0941 - accuracy: 0.9893 - val_loss: 0.0777 - val_accuracy: 1.0000
# Epoch 113/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0945 - accuracy: 0.9857 - val_loss: 0.0767 - val_accuracy: 1.0000
# Epoch 114/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0909 - accuracy: 0.9893 - val_loss: 0.0757 - val_accuracy: 1.0000
# Epoch 115/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0908 - accuracy: 0.9893 - val_loss: 0.0742 - val_accuracy: 1.0000
# Epoch 116/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0890 - accuracy: 0.9893 - val_loss: 0.0734 - val_accuracy: 1.0000
# Epoch 117/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0897 - accuracy: 0.9911 - val_loss: 0.0731 - val_accuracy: 1.0000
# Epoch 118/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0894 - accuracy: 0.9929 - val_loss: 0.0713 - val_accuracy: 1.0000
# Epoch 119/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0881 - accuracy: 0.9946 - val_loss: 0.0707 - val_accuracy: 1.0000
# Epoch 120/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0876 - accuracy: 0.9911 - val_loss: 0.0698 - val_accuracy: 1.0000
# Epoch 121/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0815 - accuracy: 0.9911 - val_loss: 0.0691 - val_accuracy: 1.0000
# Epoch 122/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0834 - accuracy: 0.9964 - val_loss: 0.0682 - val_accuracy: 1.0000
# Epoch 123/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0894 - accuracy: 0.9893 - val_loss: 0.0670 - val_accuracy: 1.0000
# Epoch 124/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0844 - accuracy: 0.9929 - val_loss: 0.0661 - val_accuracy: 1.0000
# Epoch 125/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0800 - accuracy: 0.9946 - val_loss: 0.0668 - val_accuracy: 1.0000
# Epoch 126/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0811 - accuracy: 0.9893 - val_loss: 0.0644 - val_accuracy: 1.0000
# Epoch 127/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0786 - accuracy: 0.9982 - val_loss: 0.0635 - val_accuracy: 1.0000
# Epoch 128/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0750 - accuracy: 0.9929 - val_loss: 0.0629 - val_accuracy: 1.0000
# Epoch 129/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0766 - accuracy: 0.9929 - val_loss: 0.0624 - val_accuracy: 1.0000
# Epoch 130/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0813 - accuracy: 0.9875 - val_loss: 0.0611 - val_accuracy: 1.0000
# Epoch 131/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0799 - accuracy: 0.9875 - val_loss: 0.0607 - val_accuracy: 1.0000
# Epoch 132/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0745 - accuracy: 0.9911 - val_loss: 0.0595 - val_accuracy: 1.0000
# Epoch 133/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0756 - accuracy: 0.9911 - val_loss: 0.0588 - val_accuracy: 1.0000
# Epoch 134/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0672 - accuracy: 0.9982 - val_loss: 0.0580 - val_accuracy: 1.0000
# Epoch 135/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0763 - accuracy: 0.9964 - val_loss: 0.0575 - val_accuracy: 1.0000
# Epoch 136/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0705 - accuracy: 0.9946 - val_loss: 0.0566 - val_accuracy: 1.0000
# Epoch 137/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0688 - accuracy: 0.9946 - val_loss: 0.0559 - val_accuracy: 1.0000
# Epoch 138/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0664 - accuracy: 0.9929 - val_loss: 0.0551 - val_accuracy: 1.0000
# Epoch 139/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0682 - accuracy: 0.9911 - val_loss: 0.0543 - val_accuracy: 1.0000
# Epoch 140/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0694 - accuracy: 0.9929 - val_loss: 0.0536 - val_accuracy: 1.0000
# Epoch 141/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0635 - accuracy: 0.9964 - val_loss: 0.0531 - val_accuracy: 1.0000
# Epoch 142/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0647 - accuracy: 0.9982 - val_loss: 0.0524 - val_accuracy: 1.0000
# Epoch 143/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0635 - accuracy: 0.9982 - val_loss: 0.0518 - val_accuracy: 1.0000
# Epoch 144/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0663 - accuracy: 0.9964 - val_loss: 0.0509 - val_accuracy: 1.0000
# Epoch 145/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0627 - accuracy: 0.9964 - val_loss: 0.0503 - val_accuracy: 1.0000
# Epoch 146/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0640 - accuracy: 0.9946 - val_loss: 0.0499 - val_accuracy: 1.0000
# Epoch 147/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0607 - accuracy: 0.9929 - val_loss: 0.0491 - val_accuracy: 1.0000
# Epoch 148/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0633 - accuracy: 0.9982 - val_loss: 0.0490 - val_accuracy: 1.0000
# Epoch 149/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0607 - accuracy: 0.9929 - val_loss: 0.0479 - val_accuracy: 1.0000
# Epoch 150/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0642 - accuracy: 0.9964 - val_loss: 0.0474 - val_accuracy: 1.0000
# Epoch 151/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0623 - accuracy: 0.9946 - val_loss: 0.0468 - val_accuracy: 1.0000
# Epoch 152/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0609 - accuracy: 1.0000 - val_loss: 0.0459 - val_accuracy: 1.0000
# Epoch 153/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0584 - accuracy: 0.9964 - val_loss: 0.0454 - val_accuracy: 1.0000
# Epoch 154/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0584 - accuracy: 0.9982 - val_loss: 0.0451 - val_accuracy: 1.0000
# Epoch 155/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0586 - accuracy: 0.9946 - val_loss: 0.0443 - val_accuracy: 1.0000
# Epoch 156/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0549 - accuracy: 1.0000 - val_loss: 0.0440 - val_accuracy: 1.0000
# Epoch 157/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 0.9964 - val_loss: 0.0432 - val_accuracy: 1.0000
# Epoch 158/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0579 - accuracy: 0.9946 - val_loss: 0.0425 - val_accuracy: 1.0000
# Epoch 159/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0595 - accuracy: 0.9911 - val_loss: 0.0420 - val_accuracy: 1.0000
# Epoch 160/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0544 - accuracy: 0.9982 - val_loss: 0.0419 - val_accuracy: 1.0000
# Epoch 161/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0530 - accuracy: 0.9946 - val_loss: 0.0411 - val_accuracy: 1.0000
# Epoch 162/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 1.0000
# Epoch 163/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0538 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 1.0000
# Epoch 164/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0535 - accuracy: 0.9964 - val_loss: 0.0395 - val_accuracy: 1.0000
# Epoch 165/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0479 - accuracy: 0.9964 - val_loss: 0.0391 - val_accuracy: 1.0000
# Epoch 166/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0490 - accuracy: 0.9982 - val_loss: 0.0388 - val_accuracy: 1.0000
# Epoch 167/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0442 - accuracy: 0.9982 - val_loss: 0.0381 - val_accuracy: 1.0000
# Epoch 168/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0503 - accuracy: 0.9929 - val_loss: 0.0380 - val_accuracy: 1.0000
# Epoch 169/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0512 - accuracy: 0.9946 - val_loss: 0.0373 - val_accuracy: 1.0000
# Epoch 170/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0435 - accuracy: 1.0000 - val_loss: 0.0367 - val_accuracy: 1.0000
# Epoch 171/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0459 - accuracy: 1.0000 - val_loss: 0.0365 - val_accuracy: 1.0000
# Epoch 172/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0517 - accuracy: 0.9946 - val_loss: 0.0360 - val_accuracy: 1.0000
# Epoch 173/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0475 - accuracy: 0.9946 - val_loss: 0.0355 - val_accuracy: 1.0000
# Epoch 174/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0509 - accuracy: 0.9982 - val_loss: 0.0351 - val_accuracy: 1.0000
# Epoch 175/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0468 - accuracy: 0.9964 - val_loss: 0.0345 - val_accuracy: 1.0000
# Epoch 176/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0501 - accuracy: 0.9982 - val_loss: 0.0344 - val_accuracy: 1.0000
# Epoch 177/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0460 - accuracy: 0.9946 - val_loss: 0.0341 - val_accuracy: 1.0000
# Epoch 178/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0466 - accuracy: 0.9964 - val_loss: 0.0335 - val_accuracy: 1.0000
# Epoch 179/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0470 - accuracy: 0.9964 - val_loss: 0.0330 - val_accuracy: 1.0000
# Epoch 180/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0419 - accuracy: 0.9964 - val_loss: 0.0327 - val_accuracy: 1.0000
# Epoch 181/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0412 - accuracy: 1.0000 - val_loss: 0.0322 - val_accuracy: 1.0000
# Epoch 182/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0414 - accuracy: 1.0000 - val_loss: 0.0317 - val_accuracy: 1.0000
# Epoch 183/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0457 - accuracy: 0.9946 - val_loss: 0.0315 - val_accuracy: 1.0000
# Epoch 184/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0456 - accuracy: 0.9946 - val_loss: 0.0311 - val_accuracy: 1.0000
# Epoch 185/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0441 - accuracy: 0.9964 - val_loss: 0.0307 - val_accuracy: 1.0000
# Epoch 186/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0411 - accuracy: 1.0000 - val_loss: 0.0304 - val_accuracy: 1.0000
# Epoch 187/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0367 - accuracy: 0.9982 - val_loss: 0.0300 - val_accuracy: 1.0000
# Epoch 188/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0407 - accuracy: 0.9982 - val_loss: 0.0295 - val_accuracy: 1.0000
# Epoch 189/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0400 - accuracy: 1.0000 - val_loss: 0.0293 - val_accuracy: 1.0000
# Epoch 190/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0377 - accuracy: 1.0000 - val_loss: 0.0289 - val_accuracy: 1.0000
# Epoch 191/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0395 - accuracy: 0.9982 - val_loss: 0.0286 - val_accuracy: 1.0000
# Epoch 192/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0419 - accuracy: 0.9964 - val_loss: 0.0282 - val_accuracy: 1.0000
# Epoch 193/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0380 - accuracy: 0.9982 - val_loss: 0.0278 - val_accuracy: 1.0000
# Epoch 194/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0354 - accuracy: 1.0000 - val_loss: 0.0274 - val_accuracy: 1.0000
# Epoch 195/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0368 - accuracy: 0.9982 - val_loss: 0.0272 - val_accuracy: 1.0000
# Epoch 196/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0398 - accuracy: 0.9982 - val_loss: 0.0274 - val_accuracy: 1.0000
# Epoch 197/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0380 - accuracy: 0.9982 - val_loss: 0.0265 - val_accuracy: 1.0000
# Epoch 198/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0353 - accuracy: 0.9964 - val_loss: 0.0263 - val_accuracy: 1.0000
# Epoch 199/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0361 - accuracy: 0.9982 - val_loss: 0.0263 - val_accuracy: 1.0000
# Epoch 200/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0337 - accuracy: 0.9982 - val_loss: 0.0255 - val_accuracy: 1.0000
# Epoch 201/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0332 - accuracy: 1.0000 - val_loss: 0.0253 - val_accuracy: 1.0000
# Epoch 202/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0348 - accuracy: 1.0000 - val_loss: 0.0253 - val_accuracy: 1.0000
# Epoch 203/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0383 - accuracy: 0.9964 - val_loss: 0.0250 - val_accuracy: 1.0000
# Epoch 204/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0337 - accuracy: 0.9982 - val_loss: 0.0244 - val_accuracy: 1.0000
# Epoch 205/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0356 - accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 1.0000
# Epoch 206/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0302 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 1.0000
# Epoch 207/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0346 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 1.0000
# Epoch 208/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0325 - accuracy: 0.9964 - val_loss: 0.0232 - val_accuracy: 1.0000
# Epoch 209/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0343 - accuracy: 0.9982 - val_loss: 0.0229 - val_accuracy: 1.0000
# Epoch 210/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0362 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 1.0000
# Epoch 211/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0310 - accuracy: 1.0000 - val_loss: 0.0223 - val_accuracy: 1.0000
# Epoch 212/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0331 - accuracy: 0.9964 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 213/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0332 - accuracy: 1.0000 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 214/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0356 - accuracy: 0.9964 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 215/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0373 - accuracy: 0.9964 - val_loss: 0.0211 - val_accuracy: 1.0000
# Epoch 216/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0302 - accuracy: 0.9982 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 217/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0363 - accuracy: 0.9946 - val_loss: 0.0206 - val_accuracy: 1.0000
# Epoch 218/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0296 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 219/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0329 - accuracy: 0.9946 - val_loss: 0.0202 - val_accuracy: 1.0000
# Epoch 220/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0318 - accuracy: 1.0000 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 221/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0285 - accuracy: 1.0000 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 222/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0305 - accuracy: 1.0000 - val_loss: 0.0197 - val_accuracy: 1.0000
# Epoch 223/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0284 - accuracy: 0.9982 - val_loss: 0.0196 - val_accuracy: 1.0000
# Epoch 224/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0268 - accuracy: 0.9982 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 225/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0299 - accuracy: 0.9982 - val_loss: 0.0195 - val_accuracy: 1.0000
# Epoch 226/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0284 - accuracy: 1.0000 - val_loss: 0.0194 - val_accuracy: 1.0000
# Epoch 227/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0269 - accuracy: 1.0000 - val_loss: 0.0186 - val_accuracy: 1.0000
# Epoch 228/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 0.0182 - val_accuracy: 1.0000
# Epoch 229/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0260 - accuracy: 0.9982 - val_loss: 0.0184 - val_accuracy: 1.0000
# Epoch 230/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0271 - accuracy: 1.0000 - val_loss: 0.0178 - val_accuracy: 1.0000
# Epoch 231/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0254 - accuracy: 1.0000 - val_loss: 0.0177 - val_accuracy: 1.0000
# Epoch 232/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0255 - accuracy: 0.9982 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 233/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0254 - accuracy: 0.9982 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 234/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0240 - accuracy: 1.0000 - val_loss: 0.0170 - val_accuracy: 1.0000
# Epoch 235/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.0168 - val_accuracy: 1.0000
# Epoch 236/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0232 - accuracy: 1.0000 - val_loss: 0.0167 - val_accuracy: 1.0000
# Epoch 237/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0301 - accuracy: 0.9982 - val_loss: 0.0165 - val_accuracy: 1.0000
# Epoch 238/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0259 - accuracy: 0.9982 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 239/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0255 - accuracy: 0.9982 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 240/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0226 - accuracy: 1.0000 - val_loss: 0.0163 - val_accuracy: 1.0000
# Epoch 241/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0238 - accuracy: 1.0000 - val_loss: 0.0158 - val_accuracy: 1.0000
# Epoch 242/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0232 - accuracy: 0.9982 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 243/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0254 - accuracy: 0.9982 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 244/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0242 - accuracy: 1.0000 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 245/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0243 - accuracy: 0.9982 - val_loss: 0.0151 - val_accuracy: 1.0000
# Epoch 246/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0210 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 247/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0230 - accuracy: 0.9982 - val_loss: 0.0147 - val_accuracy: 1.0000
# Epoch 248/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.0145 - val_accuracy: 1.0000
# Epoch 249/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 250/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.0145 - val_accuracy: 1.0000
# Epoch 251/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 252/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0201 - accuracy: 0.9982 - val_loss: 0.0139 - val_accuracy: 1.0000
# Epoch 253/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0212 - accuracy: 0.9982 - val_loss: 0.0141 - val_accuracy: 1.0000
# Epoch 254/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0227 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 1.0000
# Epoch 255/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0222 - accuracy: 0.9982 - val_loss: 0.0134 - val_accuracy: 1.0000
# Epoch 256/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0233 - accuracy: 0.9982 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 257/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 258/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 259/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 260/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 261/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0202 - accuracy: 0.9982 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 262/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0226 - accuracy: 0.9982 - val_loss: 0.0123 - val_accuracy: 1.0000
# Epoch 263/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 264/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 265/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 266/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 0.9982 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 267/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 268/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.9982 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 269/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0200 - accuracy: 0.9982 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 270/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 271/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 272/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 273/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.9946 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 274/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 275/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 276/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 277/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 1.0000
# Epoch 278/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 279/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0171 - accuracy: 0.9982 - val_loss: 0.0102 - val_accuracy: 1.0000
# Epoch 280/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 281/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0188 - accuracy: 0.9982 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 282/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0180 - accuracy: 0.9946 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 283/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 284/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 285/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 286/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0170 - accuracy: 0.9982 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 287/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 288/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 289/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 290/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 291/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 292/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0159 - accuracy: 0.9982 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 293/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 294/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 295/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 296/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 297/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 298/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 299/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 300/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 301/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 0.9982 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 302/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 303/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 304/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 305/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 306/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 307/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 308/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 309/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 310/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 311/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0127 - accuracy: 0.9982 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 312/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 313/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0115 - accuracy: 0.9982 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 314/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 315/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 316/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 317/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 318/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 319/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 320/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0131 - accuracy: 0.9982 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 321/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 322/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 323/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 324/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0123 - accuracy: 0.9982 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 325/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 326/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 327/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 328/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 329/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 330/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 0.9982 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 331/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0113 - accuracy: 0.9982 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 332/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 333/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 334/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# ...
# Epoch 896/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 2.6414e-04 - accuracy: 1.0000 - val_loss: 3.8518e-05 - val_accuracy: 1.0000
# Epoch 897/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 3.5454e-04 - accuracy: 1.0000 - val_loss: 3.8272e-05 - val_accuracy: 1.0000
# Epoch 898/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 4.0895e-04 - accuracy: 1.0000 - val_loss: 4.0668e-05 - val_accuracy: 1.0000
# Epoch 899/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 1.8742e-04 - accuracy: 1.0000 - val_loss: 3.8719e-05 - val_accuracy: 1.0000
# Epoch 900/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 2.9753e-04 - accuracy: 1.0000 - val_loss: 3.8031e-05 - val_accuracy: 1.0000
# Epoch 901/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.5160e-04 - accuracy: 1.0000 - val_loss: 3.6957e-05 - val_accuracy: 1.0000
# Epoch 902/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 1.4832e-04 - accuracy: 1.0000 - val_loss: 3.6603e-05 - val_accuracy: 1.0000
# Epoch 903/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 1.7512e-04 - accuracy: 1.0000 - val_loss: 3.6250e-05 - val_accuracy: 1.0000
# Epoch 904/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 2.1989e-04 - accuracy: 1.0000 - val_loss: 3.6255e-05 - val_accuracy: 1.0000
# Epoch 905/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 3.9771e-04 - accuracy: 1.0000 - val_loss: 4.1427e-05 - val_accuracy: 1.0000
# Epoch 906/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 2.5132e-04 - accuracy: 1.0000 - val_loss: 3.6689e-05 - val_accuracy: 1.0000
# Epoch 907/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 3.6564e-04 - accuracy: 1.0000 - val_loss: 3.3317e-05 - val_accuracy: 1.0000
# Epoch 908/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 3.6423e-04 - accuracy: 1.0000 - val_loss: 3.6890e-05 - val_accuracy: 1.0000
# Epoch 909/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 4.2165e-04 - accuracy: 1.0000 - val_loss: 3.6505e-05 - val_accuracy: 1.0000
# Epoch 910/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 3.2614e-04 - accuracy: 1.0000 - val_loss: 3.3410e-05 - val_accuracy: 1.0000
# Epoch 911/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 1.3242e-04 - accuracy: 1.0000 - val_loss: 3.3263e-05 - val_accuracy: 1.0000
# Epoch 912/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 2.7047e-04 - accuracy: 1.0000 - val_loss: 3.2906e-05 - val_accuracy: 1.0000
# Epoch 913/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 1.6260e-04 - accuracy: 1.0000 - val_loss: 3.3218e-05 - val_accuracy: 1.0000
# Epoch 914/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 1.8842e-04 - accuracy: 1.0000 - val_loss: 3.3926e-05 - val_accuracy: 1.0000
# Epoch 915/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 2.9961e-04 - accuracy: 1.0000 - val_loss: 3.4117e-05 - val_accuracy: 1.0000
# Epoch 916/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 2.3339e-04 - accuracy: 1.0000 - val_loss: 3.5845e-05 - val_accuracy: 1.0000
# Epoch 917/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 2.2961e-04 - accuracy: 1.0000 - val_loss: 3.4120e-05 - val_accuracy: 1.0000
# Epoch 918/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.9083e-04 - accuracy: 1.0000 - val_loss: 3.3245e-05 - val_accuracy: 1.0000
# Epoch 919/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 3.1450e-04 - accuracy: 1.0000 - val_loss: 3.2031e-05 - val_accuracy: 1.0000
# Epoch 920/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 2.6628e-04 - accuracy: 1.0000 - val_loss: 3.4899e-05 - val_accuracy: 1.0000
# Epoch 921/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 2.6121e-04 - accuracy: 1.0000 - val_loss: 3.3370e-05 - val_accuracy: 1.0000
# Epoch 922/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 1.4638e-04 - accuracy: 1.0000 - val_loss: 3.3487e-05 - val_accuracy: 1.0000
# Epoch 923/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 3.2816e-04 - accuracy: 1.0000 - val_loss: 3.1660e-05 - val_accuracy: 1.0000
# Epoch 924/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.6896e-04 - accuracy: 1.0000 - val_loss: 3.0562e-05 - val_accuracy: 1.0000
# Epoch 925/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 2.2957e-04 - accuracy: 1.0000 - val_loss: 3.1002e-05 - val_accuracy: 1.0000
# Epoch 926/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 2.6083e-04 - accuracy: 1.0000 - val_loss: 3.3456e-05 - val_accuracy: 1.0000
# Epoch 927/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 1.3272e-04 - accuracy: 1.0000 - val_loss: 3.5566e-05 - val_accuracy: 1.0000
# Epoch 928/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 2.2031e-04 - accuracy: 1.0000 - val_loss: 3.2273e-05 - val_accuracy: 1.0000
# Epoch 929/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 2.0899e-04 - accuracy: 1.0000 - val_loss: 3.1425e-05 - val_accuracy: 1.0000
# Epoch 930/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.7720e-04 - accuracy: 1.0000 - val_loss: 3.2099e-05 - val_accuracy: 1.0000
# Epoch 931/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 2.0828e-04 - accuracy: 1.0000 - val_loss: 3.2924e-05 - val_accuracy: 1.0000
# Epoch 932/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.6220e-04 - accuracy: 1.0000 - val_loss: 3.0344e-05 - val_accuracy: 1.0000
# Epoch 933/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 3.3966e-04 - accuracy: 1.0000 - val_loss: 3.2890e-05 - val_accuracy: 1.0000
# Epoch 934/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 2.1405e-04 - accuracy: 1.0000 - val_loss: 3.4440e-05 - val_accuracy: 1.0000
# Epoch 935/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.9140e-04 - accuracy: 1.0000 - val_loss: 3.2682e-05 - val_accuracy: 1.0000
# Epoch 936/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 3.6326e-04 - accuracy: 1.0000 - val_loss: 3.1434e-05 - val_accuracy: 1.0000
# Epoch 937/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 3.7730e-04 - accuracy: 1.0000 - val_loss: 3.0089e-05 - val_accuracy: 1.0000
# Epoch 938/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 3.9121e-04 - accuracy: 1.0000 - val_loss: 3.3502e-05 - val_accuracy: 1.0000
# Epoch 939/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 4.0057e-04 - accuracy: 1.0000 - val_loss: 3.3972e-05 - val_accuracy: 1.0000
# Epoch 940/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 1.3454e-04 - accuracy: 1.0000 - val_loss: 3.3624e-05 - val_accuracy: 1.0000
# Epoch 941/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.7002e-04 - accuracy: 1.0000 - val_loss: 3.1278e-05 - val_accuracy: 1.0000
# Epoch 942/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 1.2081e-04 - accuracy: 1.0000 - val_loss: 2.9863e-05 - val_accuracy: 1.0000
# Epoch 943/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.2065e-04 - accuracy: 1.0000 - val_loss: 3.0581e-05 - val_accuracy: 1.0000
# Epoch 944/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.4501e-04 - accuracy: 1.0000 - val_loss: 3.0864e-05 - val_accuracy: 1.0000
# Epoch 945/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 3.4827e-04 - accuracy: 1.0000 - val_loss: 3.2491e-05 - val_accuracy: 1.0000
# Epoch 946/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0324e-04 - accuracy: 1.0000 - val_loss: 3.1995e-05 - val_accuracy: 1.0000
# Epoch 947/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 3.3107e-04 - accuracy: 1.0000 - val_loss: 2.9416e-05 - val_accuracy: 1.0000
# Epoch 948/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 2.5105e-04 - accuracy: 1.0000 - val_loss: 3.1347e-05 - val_accuracy: 1.0000
# Epoch 949/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 2.2399e-04 - accuracy: 1.0000 - val_loss: 2.9144e-05 - val_accuracy: 1.0000
# Epoch 950/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.2576e-04 - accuracy: 1.0000 - val_loss: 2.8640e-05 - val_accuracy: 1.0000
# Epoch 951/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.3737e-04 - accuracy: 1.0000 - val_loss: 2.8338e-05 - val_accuracy: 1.0000
# Epoch 952/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.8118e-04 - accuracy: 1.0000 - val_loss: 2.8480e-05 - val_accuracy: 1.0000
# Epoch 953/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.9452e-04 - accuracy: 1.0000 - val_loss: 2.6203e-05 - val_accuracy: 1.0000
# Epoch 954/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 2.0749e-04 - accuracy: 1.0000 - val_loss: 2.7763e-05 - val_accuracy: 1.0000
# Epoch 955/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.5943e-04 - accuracy: 1.0000 - val_loss: 2.4390e-05 - val_accuracy: 1.0000
# Epoch 956/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.2947e-04 - accuracy: 1.0000 - val_loss: 2.4464e-05 - val_accuracy: 1.0000
# Epoch 957/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 2.7947e-04 - accuracy: 1.0000 - val_loss: 2.7078e-05 - val_accuracy: 1.0000
# Epoch 958/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 4.0103e-04 - accuracy: 1.0000 - val_loss: 2.5017e-05 - val_accuracy: 1.0000
# Epoch 959/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0118e-04 - accuracy: 1.0000 - val_loss: 3.1156e-05 - val_accuracy: 1.0000
# Epoch 960/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0876e-04 - accuracy: 1.0000 - val_loss: 3.0315e-05 - val_accuracy: 1.0000
# Epoch 961/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 1.6425e-04 - accuracy: 1.0000 - val_loss: 2.7639e-05 - val_accuracy: 1.0000
# Epoch 962/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0993e-04 - accuracy: 1.0000 - val_loss: 2.7342e-05 - val_accuracy: 1.0000
# Epoch 963/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 1.3603e-04 - accuracy: 1.0000 - val_loss: 2.6874e-05 - val_accuracy: 1.0000
# Epoch 964/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 2.9536e-04 - accuracy: 1.0000 - val_loss: 2.8870e-05 - val_accuracy: 1.0000
# Epoch 965/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 2.0707e-04 - accuracy: 1.0000 - val_loss: 2.7879e-05 - val_accuracy: 1.0000
# Epoch 966/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 1.7861e-04 - accuracy: 1.0000 - val_loss: 2.5257e-05 - val_accuracy: 1.0000
# Epoch 967/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 1.4203e-04 - accuracy: 1.0000 - val_loss: 2.5336e-05 - val_accuracy: 1.0000
# Epoch 968/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 1.8141e-04 - accuracy: 1.0000 - val_loss: 2.4521e-05 - val_accuracy: 1.0000
# Epoch 969/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 2.0981e-04 - accuracy: 1.0000 - val_loss: 2.3734e-05 - val_accuracy: 1.0000
# Epoch 970/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 2.0600e-04 - accuracy: 1.0000 - val_loss: 2.5195e-05 - val_accuracy: 1.0000
# Epoch 971/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 4.2180e-04 - accuracy: 1.0000 - val_loss: 4.0014e-05 - val_accuracy: 1.0000
# Epoch 972/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.8246e-04 - accuracy: 1.0000 - val_loss: 2.8618e-05 - val_accuracy: 1.0000
# Epoch 973/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 2.3624e-04 - accuracy: 1.0000 - val_loss: 2.7662e-05 - val_accuracy: 1.0000
# Epoch 974/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 3.0452e-04 - accuracy: 1.0000 - val_loss: 2.7113e-05 - val_accuracy: 1.0000
# Epoch 975/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 2.5169e-04 - accuracy: 1.0000 - val_loss: 2.4081e-05 - val_accuracy: 1.0000
# Epoch 976/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 2.4049e-04 - accuracy: 1.0000 - val_loss: 2.3364e-05 - val_accuracy: 1.0000
# Epoch 977/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 1.2589e-04 - accuracy: 1.0000 - val_loss: 2.4325e-05 - val_accuracy: 1.0000
# Epoch 978/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 2.6427e-04 - accuracy: 1.0000 - val_loss: 2.8549e-05 - val_accuracy: 1.0000
# Epoch 979/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 2.3444e-04 - accuracy: 1.0000 - val_loss: 2.3554e-05 - val_accuracy: 1.0000
# Epoch 980/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 1.2984e-04 - accuracy: 1.0000 - val_loss: 2.3385e-05 - val_accuracy: 1.0000
# Epoch 981/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.2240e-04 - accuracy: 1.0000 - val_loss: 2.2513e-05 - val_accuracy: 1.0000
# Epoch 982/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.3271e-04 - accuracy: 1.0000 - val_loss: 2.1081e-05 - val_accuracy: 1.0000
# Epoch 983/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 1.0171e-04 - accuracy: 1.0000 - val_loss: 2.0626e-05 - val_accuracy: 1.0000
# Epoch 984/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 2.3404e-04 - accuracy: 1.0000 - val_loss: 2.1154e-05 - val_accuracy: 1.0000
# Epoch 985/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 1.3309e-04 - accuracy: 1.0000 - val_loss: 2.1334e-05 - val_accuracy: 1.0000
# Epoch 986/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.4273e-04 - accuracy: 1.0000 - val_loss: 2.2131e-05 - val_accuracy: 1.0000
# Epoch 987/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 8.8812e-05 - accuracy: 1.0000 - val_loss: 2.2100e-05 - val_accuracy: 1.0000
# Epoch 988/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.0454e-04 - accuracy: 1.0000 - val_loss: 2.2230e-05 - val_accuracy: 1.0000
# Epoch 989/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.9621e-05 - accuracy: 1.0000 - val_loss: 2.1702e-05 - val_accuracy: 1.0000
# Epoch 990/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 2.3331e-04 - accuracy: 1.0000 - val_loss: 2.2755e-05 - val_accuracy: 1.0000
# Epoch 991/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.5050e-04 - accuracy: 1.0000 - val_loss: 2.5438e-05 - val_accuracy: 1.0000
# Epoch 992/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.6995e-04 - accuracy: 1.0000 - val_loss: 2.6493e-05 - val_accuracy: 1.0000
# Epoch 993/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 1.7940e-04 - accuracy: 1.0000 - val_loss: 2.3881e-05 - val_accuracy: 1.0000
# Epoch 994/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.1054e-04 - accuracy: 1.0000 - val_loss: 2.2280e-05 - val_accuracy: 1.0000
# Epoch 995/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.0129e-04 - accuracy: 1.0000 - val_loss: 2.0020e-05 - val_accuracy: 1.0000
# Epoch 996/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 8.1851e-05 - accuracy: 1.0000 - val_loss: 1.9808e-05 - val_accuracy: 1.0000
# Epoch 997/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 3.8897e-04 - accuracy: 1.0000 - val_loss: 2.2646e-05 - val_accuracy: 1.0000
# Epoch 998/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.8473e-04 - accuracy: 1.0000 - val_loss: 2.3403e-05 - val_accuracy: 1.0000
# Epoch 999/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.7281e-04 - accuracy: 1.0000 - val_loss: 2.0458e-05 - val_accuracy: 1.0000
# Epoch 1000/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 1.0481e-04 - accuracy: 1.0000 - val_loss: 1.9215e-05 - val_accuracy: 1.0000

# %%
#-----------------------------------------------------------------------------------------------------------
#Plot the architecture (with netron)
#-----------------------------------------------------------------------------------------------------------
from tensorflow.keras.utils import plot_model
import pydot
#for this to work pip install pydot
#install graphviz.exe for windows: https://graphviz.gitlab.io/download/

#Save the model:
#model.save('./figures%s/Planck_NN_model.h5' %PS)

import netron
#netron.start('./figures%s/Planck_NN_model.h5' %PS)

# %% [markdown]
# ### Learning curves visualization

# %%
#-----------------------------------------------------------------------------------------------------------
#Accuracy plot
#-----------------------------------------------------------------------------------------------------------
fig = plt.figure(figsize=(8,6))
plt.plot(History.history['accuracy'])
plt.plot(History.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='lower right')
plt.grid(color='lightgray', linestyle='--')
plt.show()

# %%
#-----------------------------------------------------------------------------------------------------------
#Loss plot
#-----------------------------------------------------------------------------------------------------------
fig = plt.figure(figsize=(8,6))
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.grid(color='lightgray', linestyle='--')
plt.show()

# %% [markdown]
# ### Testing the NNs

# %%
#Function for the probability of classification as LCDM 
def normFeat(p):
  if 0<p<0.5:
    rr=1-p
  else:
    rr=p
  return rr

#Function for the probability of classification as Feature 
def normLCDM(p):
  if 0<p<0.5:
    rr=p
  else:
    rr=1-p
  return rr

# %%
#-----------------------------------------------------------------------------------------------------------
#Test the NN
#-----------------------------------------------------------------------------------------------------------
theory = ['LCDM','FT']

true_model=[]
pred_model=[]
prob_pred_MoG=[]
prob_pred_LCDM=[]
for i in range(len(X_test)):
  X_test_tf = tf.convert_to_tensor([X_test[i]])
  predictions = model.predict(X_test_tf)
  true_model.append(round(y_test[i]))
  pred_model.append(round(predictions[0][0]))
  prob_pred_MoG.append(round(100*normFeat(predictions[0][0]),3))
  prob_pred_LCDM.append(round(100*normLCDM(predictions[0][0]),3))
# Out:
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 24ms/step

# %% [markdown]
# ### Performance verification of the NNs

# %%
#-----------------------------------------------------------------------------------------------------------
#Performance: correct & incorrect  predictions
#-----------------------------------------------------------------------------------------------------------
true_LCDM = []
true_MoG = []
false_LCDM = []
false_MoG = []

for pred, true in zip(pred_model, true_model):
    if pred==0 and true==0:
        true_LCDM.append(1)
    if pred==1 and true==1:
        true_MoG.append(1)
    if pred==0 and true==1:
        false_LCDM.append(1)
    if pred==1 and true==0:
        false_MoG.append(1)
lenghts=[len(true_LCDM),len(true_MoG),len(false_LCDM),len(false_MoG)]

print('     ','LCDM','MoG')
print('True ',len(true_LCDM)/sum(lenghts),len(true_MoG)/sum(lenghts))
print('False',len(false_LCDM)/sum(lenghts),len(false_MoG)/sum(lenghts))
print('--------------')
print("Correct prediction: ",(len(true_LCDM)+len(true_MoG))/sum(lenghts))
print("Wrong prediction  : ",(len(false_LCDM)+len(false_MoG))/sum(lenghts))
# Out:
#       LCDM MoG
# True  0.5 0.5
# False 0.0 0.0
# --------------
# Correct prediction:  1.0
# Wrong prediction  :  0.0

# %%
#-----------------------------------------------------------------------------------------------------------
#Probability distribution of classification as Feature
#-----------------------------------------------------------------------------------------------------------
fig = plt.figure(figsize=(8,6))
plt.hist(prob_pred_MoG, label='Feature', alpha=0.6, color='#FF7F0E')
plt.xlabel('Predicted probability')
plt.ylabel('Number of samples')
plt.legend()
plt.show()

# %%
#-----------------------------------------------------------------------------------------------------------
#Probability distribution of classification as LCDM
#-----------------------------------------------------------------------------------------------------------
fig = plt.figure(figsize=(8,6))
plt.hist(prob_pred_LCDM, label='$\Lambda$CDM', alpha=0.6)
plt.xlabel('Predicted probability')
plt.ylabel('Number of samples')
plt.legend()
plt.show()

# %%
#-----------------------------------------------------------------------------------------------------------
##Confusion matrix
#-----------------------------------------------------------------------------------------------------------
from sklearn import metrics
import seaborn as sns
fsize=18
cm = metrics.confusion_matrix(true_model, pred_model)

#Create normalized Confusion Matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

heatmap = sns.heatmap(cm_normalized, 
            annot=True, 
            annot_kws={"size": fsize},
            linewidths=0.01,
            fmt='g', 
            xticklabels=['$\Lambda$CDM', 'Feature'],
            yticklabels=['$\Lambda$CDM', 'Feature'], cmap='RdPu')
plt.xlabel('Predicted Class', fontsize=fsize, labelpad=15)
plt.ylabel('True Class', fontsize=fsize, labelpad=15)

plt.xticks(fontsize=fsize)
plt.yticks(fontsize=fsize)

num_ticks = 2  
x_ticks = np.array([0, 1])
colorbar = heatmap.collections[0].colorbar
colorbar.ax.set_yticks(np.linspace(0, 1, num_ticks))
colorbar.ax.set_yticklabels(x_ticks, fontsize=fsize)

plt.title('$\;$\n\n$C_{\ell}^{EE}$', fontsize=20)
plt.tight_layout()
plt.savefig('./figures_feature/conf_matrix_EE_feature.pdf')
plt.show()

# %%
#Read real Planck data
Full_planck_TE = np.genfromtxt('./experimental_data/COM_PowerSpect_CMB-TE-binned_R3.02.txt', 
                          delimiter=None, skip_header=1, comments='#')
planck_TE = [Full_planck_TE[i,4] for i in range(len(Full_planck_TE))]

# %%
#Test NN on real Planck data (best fit)
Planck_label = model.predict(tf.convert_to_tensor([planck_TE]))
# Out:
# 1/1 [==============================] - 0s 82ms/step

# %%
print("The data belongs to the class:",Planck_label[0][0])
# Out:
# The data belongs to the class: 0.0
